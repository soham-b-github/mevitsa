# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/
# python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/musait/all_info.csv')
df.head()
# Out:
#            filename                                           filepath  \
# 0  negative_001.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 1  negative_002.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 2  negative_003.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 3  negative_004.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 4  negative_005.jpg  /kaggle/input/musait/dataset/basket/negative_0...
#
#    text-detected                                                OCR  \
# 0              1   STOP WAR\nUKRAINE\nIN\nСлава Україні!\nMAKE\nNOT
# 1              1  HUNDREDS\nKILLED IN\nUKRAINE\n>NEWS\nNIGHTLY AT 6
# 2              0                                                NaN
# 3              0                                                NaN
# 4              1  HUNDREDS\nKILLED IN\nUKRAINE\n>NEWS\nNIGHTLY AT 6
#
#                                          coordinates img_ar      img_or  \
# 0  [{'x': 513, 'y': 24}, {'x': 975, 'y': 24}, {'x...   16:9  horizontal
# 1  [{'x': 20, 'y': 61}, {'x': 508, 'y': 61}, {'x'...   16:9  horizontal
# 2                                                 []   16:9  horizontal
# 3                                                 []    4:3  horizontal
# 4  [{'x': 20, 'y': 61}, {'x': 508, 'y': 61}, {'x'...   16:9  horizontal
#
#    img_area txt_ar      txt_or  txt_area  txt_img_ratio sentiment
# 0    535824   16:9  horizontal    110418       0.206071  negative
# 1    921600    3:4    vertical    313784       0.340477  negative
# 2    810000    NaN         NaN         0       0.000000  negative
# 3     50246    NaN         NaN         0       0.000000  negative
# 4    921600    3:4    vertical    313784       0.340477  negative

# %% [markdown]
# # Duplicate Check

# %%
sentiments = df['sentiment']
sentiments.value_counts()
# Out:
# sentiment
# positive    1021
# neutral      947
# negative     907
# Name: count, dtype: int64

# %%
negatives = df[df['sentiment']=='negative']
neutrals = df[df['sentiment']=='neutral']
positives = df[df['sentiment']=='positive']

# %%
import os
import hashlib
from tqdm.notebook import tqdm

# Path to your folder of images
folder_path = '/kaggle/input/musait/dataset/basket'

# Dictionary to store hashes
hash_dict = {}

# Get all filenames first
filenames = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]


# Loop through files
for filename in tqdm(filenames, desc="Scanning images"):
    file_path = os.path.join(folder_path, filename)
    
    # Only process files (not subfolders)
    if os.path.isfile(file_path):
        # Read file in binary mode
        with open(file_path, 'rb') as f:
            file_data = f.read()
            file_hash = hashlib.md5(file_data).hexdigest()  # You can also use sha256

        # Store duplicates
        if file_hash in hash_dict:
            hash_dict[file_hash].append(filename)
        else:
            hash_dict[file_hash] = [filename]

# Print duplicates
duplicates = {h: files for h, files in hash_dict.items() if len(files) > 1}

if duplicates:
    print(f"Found {len(duplicates)} duplicate images:")
    for h, files in duplicates.items():
        print(f"\nHash: {h}")
        for f in files:
            print(f"  - {f}")
else:
    print("No duplicate images found.")
# Out:
# Scanning images:   0%|          | 0/2875 [00:00<?, ?it/s]
# Found 771 duplicate images:
#
# Hash: b569086b817a038d41113ee301b2d308
#   - negative_629.jpeg
#   - negative_630.jpeg
#
# Hash: b32779399718428b020abb229eb5bcee
#   - neutral_213.jpg
#   - neutral_179.jpg
#   - neutral_212.jpg
#   - neutral_178.jpg
#
# Hash: 618613a1cea39d7206283074039e36bc
#   - negative_188.jpg
#   - negative_189.jpg
#
# Hash: edd2d54cd05db6edc1c2b342b7871aec
#   - positive_301.jpeg
#   - positive_302.jpeg
#
# Hash: 6f19ed0bfa94798bebe3f5b3b86b9a84
#   - positive_525.jpeg
#   - positive_524.jpeg
#
# Hash: 9a3fbd1c69781f4c855b3f46906a1f94
#   - neutral_414.jpeg
#   - neutral_415.jpeg
#
# Hash: 5ba8f490685833c5296d01826ddec0de
#   - positive_223.jpeg
#   - positive_222.jpeg
#
# Hash: b3b807cca63f5d7e4260fce586df80af
#   - positive_297.jpeg
#   - positive_298.jpeg
#
# Hash: 914eebbab7a88bba6e2a6e979ef02b46
#   - positive_728.jpg
#   - positive_960.jpg
#
# Hash: 9aa4e69e9b601bab0bc39a96140469f4
#   - neutral_485.jpeg
#   - neutral_486.jpeg
#
# Hash: d6cd0b4d9296c40973560c2ffc0a2a27
#   - positive_249.jpg
#   - positive_250.jpg
#
# Hash: 33aca593797db0c85385e3d800e71513
#   - neutral_494.jpeg
#   - neutral_493.jpeg
#
# Hash: 1e84cf6ab126afde471f8e38928db945
#   - neutral_381.jpg
#   - neutral_380.jpg
#
# Hash: a8700da5398415797d9bed465c783cab
#   - positive_371.png
#   - positive_372.png
#
# Hash: 00d91b27dd1dc710b94559d50ba54e87
#   - negative_379.jpg
#   - negative_378.jpg
#
# Hash: 0cfd934e5383421fba22ae8c7ad94b77
#   - neutral_504.jpeg
#   - neutral_505.jpeg
#
# Hash: ee0effb7a72f483be638b67b4569141e
#   - neutral_407.jpeg
#   - neutral_406.jpeg
#
# Hash: 770dc9a30be080fb344019b1bf1e4bed
#   - neutral_146.png
#   - neutral_145.png
#
# Hash: 050c5fda4ded6df8aadbb8b4589f42b4
#   - negative_130.jpeg
#   - negative_128.jpeg
#
# Hash: 5211d655dbf7ba177661bc043e17a5f7
#   - positive_041.jpeg
#   - positive_039.jpeg
#
# Hash: 717e95e3133a4a961f5757d379ac05d2
#   - negative_404.jpeg
#   - negative_405.jpeg
#
# Hash: 3bc0698bf4ec9ba6bb2f7cab15afa7d8
#   - positive_064.jpeg
#   - positive_937.jpeg
#
# Hash: 610e6882fa1abb0babc522fbb092c730
#   - negative_343.jpeg
#   - negative_342.jpeg
#
# Hash: ea8450519af31b63e1eee108316e9e4f
#   - negative_364.jpg
#   - negative_365.jpg
#
# Hash: 46d0f619e6c90f790cc3657c4595d083
#   - negative_225.jpg
#   - negative_224.jpg
#
# Hash: e1e97acc78c3accb05a39d03ad310a7c
#   - positive_417.png
#   - positive_416.png
#
# Hash: a6303c0ae6f51007934e83a10a1d607d
#   - positive_901.jpg
#   - positive_707.jpg
#
# Hash: df6d634a2a3f3375f085158a070472d6
#   - neutral_170.png
#   - neutral_169.png
#
# Hash: 8dc37ef1032969c7786392b637bcbcfc
#   - neutral_558.jpg
#   - neutral_557.jpg
#
# Hash: cc5f91e1067e36e7d69b2b368be859cf
#   - neutral_449.jpg
#   - neutral_450.jpg
#
# Hash: e050b9f51fea86a64a8fba080308cb08
#   - neutral_228.jpeg
#   - neutral_229.jpeg
#
# Hash: 11af142f52a6de16dde2a7497c3ffb2e
#   - positive_618.jpeg
#   - positive_617.jpeg
#
# Hash: ec55bd9695a80ba7cdcaac1aac6634db
#   - neutral_022.jpg
#   - neutral_589.jpg
#   - neutral_025.jpg
#   - neutral_590.jpg
#
# Hash: 3fe6a9ad3a46a58ee859f377bb87a1bf
#   - negative_352.jpeg
#   - negative_353.jpeg
#
# Hash: 212ab64d4ee106d848845efa4a395c86
#   - negative_171.jpg
#   - negative_170.jpg
#
# Hash: d73f5fa08fb2f0f6c8ac0ddfc6d792bb
#   - neutral_017.jpg
#   - neutral_020.jpg
#   - neutral_585.jpg
#   - neutral_586.jpg
#
# Hash: ddbd6951a1cde1f1c523e4bcf453c2a7
#   - negative_585.jpg
#   - negative_155.jpg
#   - negative_584.jpg
#
# Hash: d984a32f7b1a071e5c540395dd27233d
#   - negative_262.jpg
#   - negative_263.jpg
#
# Hash: fc18230583853bd240318d6608cd8f41
#   - neutral_563.jpeg
#   - neutral_564.jpeg
#
# Hash: b1bb5f7daee142ebb61835064d714ada
#   - positive_588.jpeg
#   - positive_587.jpeg
#
# Hash: 1007ea2595776f088fa3c220b4519191
#   - negative_587.jpg
#   - negative_586.jpg
#   - negative_158.jpg
#
# Hash: cf932e253174d81ddb0d3458f065c838
#   - positive_207.jpeg
#   - positive_208.jpeg
#
# Hash: ed58613163fe2d3419c879f2a5d4098a
#   - neutral_621.jpeg
#   - neutral_622.jpeg
#
# Hash: ad57dfa3046c33006d96986af45b1e08
#   - positive_454.jpeg
#   - positive_453.jpeg
#
# Hash: 97e040a3642dc54cd74076c9a3d24aa2
#   - positive_513.jpeg
#   - positive_512.jpeg
#
# Hash: c46554217858ac91e3b3f4c124a53d94
#   - negative_377.jpeg
#   - negative_376.jpeg
#
# Hash: 4e0853fefb332bf65b905938fe4d4e49
#   - neutral_593.jpeg
#   - neutral_594.jpeg
#
# Hash: e07df69313fde8010cc63a242ba755eb
#   - negative_509.jpeg
#   - negative_508.jpeg
#
# Hash: 65aaefc2a1078cee12344ff5899def3c
#   - negative_081.jpg
#   - negative_083.jpg
#
# Hash: cf9b26ce9e3407e955a4ee246c7a8719
#   - neutral_176.png
#   - neutral_175.png
#
# Hash: 271d6510165f094691b9b27cefc90b6b
#   - neutral_154.png
#   - neutral_155.png
#
# Hash: e142931dac0985cd9294c733c1bcac85
#   - positive_581.jpeg
#   - positive_580.jpeg
#
# Hash: b1430d0e898140f11649c63b93880abf
#   - negative_331.jpeg
#   - negative_330.jpeg
#
# Hash: 6b3e8eacea9115578454a91b1e0eb006
#   - positive_535.jpeg
#   - positive_536.jpeg
#
# Hash: a3ebf19d226edf105bd86d03187b4dac
#   - neutral_140.jpeg
#   - neutral_138.jpeg
#
# Hash: 9a056793562f88a1264947bd057d9284
#   - positive_070.png
#   - positive_938.png
#
# Hash: a54b6339a82b065a816129d70e6d7f0e
#   - negative_278.jpeg
#   - negative_279.jpeg
#
# Hash: b833c7ef61f9b2e8dec24feebc8d0edc
#   - neutral_343.jpeg
#   - neutral_344.jpeg
#
# Hash: c9662bbd10023cfac60817317e70013f
#   - negative_907.jpg
#   - negative_245.jpg
#   - negative_244.jpg
#
# Hash: 82442d23e949c8b97fed6f0fac37e3ad
#   - neutral_313.jpeg
#   - neutral_314.jpeg
#
# Hash: 3f2d5843084173e345e369ee75c15bc7
#   - positive_488.jpeg
#   - positive_487.jpeg
#
# Hash: 54f946b48a54f1f997414c2545588ec2
#   - negative_474.jpeg
#   - negative_475.jpeg
#
# Hash: 2c3442de7490bb52bfd8a770ec645b65
#   - neutral_219.jpg
#   - neutral_218.jpg
#
# Hash: 2f66d0bc6cec3101e544b0aebfc4f0ce
#   - positive_329.jpg
#   - positive_330.jpg
#
# Hash: 4cf9229f382db30bdaabc5fcacab767f
#   - positive_579.jpeg
#   - positive_578.jpeg
#
# Hash: 051b3625448b584840769b9a4b1303cc
#   - positive_373.jpeg
#   - positive_374.jpeg
#
# Hash: 197e1c1245f247f9c0309db73ace36a1
#   - negative_227.jpg
#   - negative_226.jpg
#
# Hash: 265b02af75c0c28e52fbd2eab34d927a
#   - neutral_583.jpeg
#   - neutral_584.jpeg
#
# Hash: 4d86be2b911ab8063b25c1838cbcfa77
#   - negative_388.jpeg
#   - negative_389.jpeg
#
# Hash: 7ee6d243fe0306f57a9652055b40dc22
#   - positive_429.jpeg
#   - positive_428.jpeg
#
# Hash: e144b75c85534d851b66d2a34ab8b687
#   - negative_230.jpg
#   - negative_231.jpg
#
# Hash: e01c63c21ec1257436ecce1e4ef2c465
#   - neutral_599.jpg
#   - neutral_598.jpg
#
# Hash: ea096261c8f8c91eca1092eac25f7602
#   - positive_310.jpeg
#   - positive_309.jpeg
#
# Hash: 7d5fb2aabc4fe1d5d69de853969dee51
#   - positive_148.jpeg
#   - positive_146.jpeg
#
# Hash: b2469b657fd0d72e9ba1a3596f6fe02b
#   - positive_190.jpg
#   - positive_189.jpg
#
# Hash: ea753da5605fa15ca0a6b60e4b9ab9bc
#   - negative_141.jpg
#   - negative_139.jpg
#
# Hash: 004a67aac5805e322ff1fae7adf38472
#   - negative_285.jpg
#   - negative_369.jpg
#   - negative_368.jpg
#   - negative_284.jpg
#
# Hash: 2057102ff29f9f15e563c7aa2c8fb193
#   - neutral_639.jpg
#   - neutral_640.jpg
#
# Hash: f98ce1cc5eff5b0a22269db1a5634249
#   - neutral_439.jpg
#   - neutral_438.jpg
#
# Hash: 39a97df58204d623fec5a9aa0c696381
#   - positive_470.jpeg
#   - positive_471.jpeg
#
# Hash: 91a587219b8568883b9c71b345eb9950
#   - neutral_116.jpeg
#   - neutral_118.jpeg
#
# Hash: 965c9b39c1f300fc088f9a468b33f2f8
#   - neutral_094.jpeg
#   - neutral_093.jpeg
#
# Hash: aaa488017faee0f877940fe18099cf85
#   - positive_509.jpeg
#   - positive_510.jpeg
#
# Hash: 5a8259f0583b979c8cfbc8862a5ab04f
#   - negative_488.jpg
#   - negative_489.jpg
#
# Hash: 5667251f949b237a78b7f0b8c4a931c2
#   - positive_295.jpeg
#   - positive_296.jpeg
#
# Hash: 6e9c999fc56a9bd56920a9841c502d0e
#   - neutral_616.jpg
#   - neutral_617.jpg
#
# Hash: ae0fc760149b73f040f825647541d30d
#   - neutral_045.jpg
#   - neutral_042.jpg
#
# Hash: d0e9465dbfab500d8ab03070a552761e
#   - negative_413.jpeg
#   - negative_412.jpeg
#
# Hash: 0e55a36056f0b0ed749d552cbb24ecc7
#   - neutral_416.jpg
#   - neutral_417.jpg
#
# Hash: 83f9cb7b41e3814b7b8429bfe0331a43
#   - neutral_302.jpeg
#   - neutral_301.jpeg
#
# Hash: 66f6f72df3dea46e96d677eb97daa30b
#   - negative_324.jpeg
#   - negative_325.jpeg
#
# Hash: 1579cb1e8781d3e183600f96684f07f7
#   - positive_240.jpg
#   - positive_239.jpg
#
# Hash: eaad5d900676c0f0f103bcc12c9bb125
#   - neutral_389.jpg
#   - neutral_388.jpg
#
# Hash: 0fbabe1460abddce10b625aaefa40a5a
#   - positive_187.jpg
#   - positive_188.jpg
#
# Hash: 0480034a0a3a31c1cfaf551e60949d8a
#   - neutral_582.jpg
#   - neutral_012.jpg
#   - neutral_581.jpg
#   - neutral_015.jpg
#
# Hash: df24421d2664bf0455afaba15a22e6ba
#   - positive_635.jpg
#   - positive_636.jpg
#   - positive_634.jpg
#
# Hash: 9e607bd833dc2692840e84aa8aa9dfb7
#   - neutral_185.png
#   - neutral_186.png
#
# Hash: 342e3d04666d045ef4238a4f80f99212
#   - negative_235.jpg
#   - negative_234.jpg
#
# Hash: 65b4db5c0f4ca1f25d14e4116b4ad058
#   - neutral_266.jpeg
#   - neutral_267.jpeg
#
# Hash: 1127925a7668fd2b80dca8120d05d935
#   - neutral_253.jpeg
#   - neutral_252.jpeg
#
# Hash: f73c026b7355fd071d471dfaa25fa1e1
#   - positive_181.jpeg
#   - positive_182.jpeg
#
# Hash: 6cc6d3bbd278647b7a27722a1c4ed77b
#   - neutral_427.jpg
#   - neutral_428.jpg
#
# Hash: 76a7b1b14ef71a357b131931613db761
#   - negative_030.jpg
#   - negative_027.jpg
#
# Hash: 43198f4b5387284ba28a98cf51718d80
#   - neutral_293.jpeg
#   - neutral_294.jpeg
#
# Hash: 8a4a554278524330d18cd5a90498ef01
#   - positive_480.jpg
#   - positive_479.jpg
#   - positive_136.jpg
#
# Hash: 16854fdefd3cdbf24052e5839a099246
#   - positive_591.jpeg
#   - positive_592.jpeg
#
# Hash: 8c5f7a637bb6c819928e04c15ac415e3
#   - neutral_483.jpg
#   - neutral_484.jpg
#
# Hash: 1f627b1bab8e16be102823f9a9d8393b
#   - neutral_350.jpg
#   - neutral_349.jpg
#
# Hash: 1c0d04b6642733fa42666c045d56958f
#   - neutral_625.jpeg
#   - neutral_626.jpeg
#
# Hash: 08fb38166ecd8f2617752f81b7c5865c
#   - positive_335.jpeg
#   - positive_336.jpeg
#
# Hash: 5e284dade9891ec906be36c95b7def3e
#   - negative_210.jpeg
#   - negative_211.jpeg
#
# Hash: 3efacb99d4cfdf3cab942009ef592855
#   - neutral_431.jpg
#   - neutral_432.jpg
#
# Hash: 2762c50cdee5e9c45eb7b58f3ae4f177
#   - negative_902.jpeg
#   - negative_076.jpeg
#
# Hash: 1a78b0800f9572b02e3b8c1cea24d57d
#   - negative_571.jpeg
#   - negative_572.jpeg
#
# Hash: 74f94bc2633ecc836f718e21f063ed71
#   - positive_485.jpeg
#   - positive_484.jpeg
#
# Hash: f356f0cba7b9b9d43701e038b82e59cc
#   - positive_437.jpeg
#   - positive_438.jpeg
#
# Hash: b107de0ddcafa632d8cdb12e2faf2f7c
#   - neutral_469.jpeg
#   - neutral_470.jpeg
#
# Hash: f09d865e76e51aef38499252faa1ad1c
#   - positive_256.jpg
#   - positive_257.jpg
#
# Hash: 5cc174663770d4227c5e94248decc60f
#   - negative_216.jpg
#   - negative_217.jpg
#
# Hash: 4fa422e58d0ea6a8354ed00392089b41
#   - neutral_211.jpeg
#   - neutral_270.jpeg
#   - neutral_210.jpeg
#   - neutral_271.jpeg
#
# Hash: 261766ecd58305e9d9b30716a3a7cbfd
#   - positive_566.jpeg
#   - positive_567.jpeg
#
# Hash: ac5f700b0cfd1275d5decc44a66e900c
#   - positive_317.jpeg
#   - positive_318.jpeg
#
# Hash: f900f210befe1632ffca4eb34956e37a
#   - neutral_306.jpeg
#   - neutral_305.jpeg
#
# Hash: 0f30a7df983816b69b43be4acf6bfa88
#   - negative_213.jpeg
#   - negative_212.jpeg
#
# Hash: ecf4824430360562df2622b746dbb37f
#   - negative_318.jpeg
#   - negative_319.jpeg
#
# Hash: 7e0222e5343a46a9159208f8011e1788
#   - negative_545.jpeg
#   - negative_544.jpeg
#
# Hash: 8f63ac413b8f08b1a06e8bd25f511139
#   - negative_115.jpg
#   - negative_113.jpg
#
# Hash: c97672bb834ec2002c9bd3f1cfdfcdfb
#   - neutral_311.jpg
#   - neutral_312.jpg
#
# Hash: ec818f338b3e566663d050045dcc82fc
#   - positive_391.jpeg
#   - positive_390.jpeg
#
# Hash: 35e10a533a1cb8fcc8e2d5c816973418
#   - negative_429.jpg
#   - negative_428.jpg
#
# Hash: cbf42463510413294c9d540b71291972
#   - positive_598.jpeg
#   - positive_599.jpeg
#
# Hash: cf0fc9ebb3ce9e202babc31c1f150372
#   - neutral_546.jpg
#   - neutral_547.jpg
#
# Hash: 2c88f3de65a4dacb9f0715566569fa3e
#   - negative_168.jpg
#   - negative_169.jpg
#
# Hash: c1827078df948046f298d99457378b24
#   - neutral_338.jpg
#   - neutral_337.jpg
#
# Hash: df3f0aec8074e11de1eb127fc63d70e1
#   - negative_362.jpeg
#   - negative_363.jpeg
#
# Hash: 91876790bbb07933bb31debe5df9e458
#   - neutral_232.png
#   - neutral_233.png
#
# Hash: 67c778181c0df964b076b12ae0451739
#   - neutral_376.jpg
#   - neutral_377.jpg
#
# Hash: 38b3f0083d962d5e52908f40e226fc29
#   - positive_469.jpg
#   - positive_468.jpg
#   - positive_125.jpg
#
# Hash: 3f37732dc8b50af4a57b3086d103866d
#   - negative_422.jpeg
#   - negative_423.jpeg
#
# Hash: 02256d5d9b4a731ffd7a2c0b89557212
#   - neutral_364.jpeg
#   - neutral_363.jpeg
#
# Hash: e1d5409e30561fb3107a9675eff9046f
#   - negative_159.jpeg
#   - negative_157.jpeg
#
# Hash: dca3935c0eafd97083ecfb3c2951caa1
#   - negative_206.jpeg
#   - negative_207.jpeg
#
# Hash: 0ae275b15cba966579ae417575fa803f
#   - positive_556.jpeg
#   - positive_557.jpeg
#
# Hash: abd0ae61fa5abe05d6dfd1b66466eb59
#   - negative_514.jpeg
#   - negative_515.jpeg
#
# Hash: 5f781e2684bd6274c388f62e3dc2703d
#   - negative_453.jpeg
#   - negative_452.jpeg
#
# Hash: 31f393b5e86e8e6ee4096b0842da26db
#   - neutral_223.jpeg
#   - neutral_222.jpeg
#
# Hash: 64d1538c9385195cfd5fdd66a7b56db7
#   - negative_354.jpeg
#   - negative_355.jpeg
#
# Hash: 31fef6c2c15ab34a3e85b6a5a844fce7
#   - negative_347.jpeg
#   - negative_346.jpeg
#
# Hash: 1de163b931321ff50e26feea89b62a0e
#   - positive_225.jpeg
#   - positive_224.jpeg
#
# Hash: 1ef40d613efbc6239581f0c447071468
#   - positive_620.jpeg
#   - positive_619.jpeg
#
# Hash: a023ad24b541b1695b9b6fa669bc5f86
#   - negative_439.jpeg
#   - negative_440.jpeg
#
# Hash: 307c732955729f9ea5f51ca2d1f856b4
#   - negative_406.jpeg
#   - negative_407.jpeg
#
# Hash: a4424bdd28a0a4e2557209185dbd5576
#   - neutral_559.jpeg
#   - neutral_560.jpeg
#
# Hash: 5a21ab4ed08a1248d4ff5d3b1aa60964
#   - neutral_366.jpg
#   - neutral_365.jpg
#
# Hash: fc9fb9401c8036851ea7ceac34a33c9c
#   - positive_277.jpg
#   - positive_278.jpg
#
# Hash: 17c88bf3a18a223de9f688d70877f1aa
#   - negative_540.jpeg
#   - negative_541.jpeg
#
# Hash: 8387aaa3c17f171956da375236192c7b
#   - positive_464.jpeg
#   - positive_463.jpeg
#
# Hash: 701cb32b09df75ea45e60a288032fc4c
#   - positive_103.jpeg
#   - positive_102.jpeg
#
# Hash: 88061fa4b7a89c5d558e1a9b6c107f46
#   - negative_260.jpg
#   - negative_261.jpg
#
# Hash: a804df05f3736bb7b390ce533b9a3441
#   - neutral_243.png
#   - neutral_244.png
#
# Hash: 157ebc90da6a0df939e2148bd3e767ba
#   - neutral_316.jpg
#   - neutral_315.jpg
#
# Hash: 57d4def9c7d42bf546ce00789be3f522
#   - positive_099.jpeg
#   - positive_098.jpeg
#
# Hash: 99dc91906262598836c053dc77542e36
#   - positive_626.jpg
#   - positive_625.jpg
#
# Hash: 3e8a9bdadde9c88f189ef4261494eafd
#   - neutral_096.jpg
#   - neutral_098.jpg
#
# Hash: 1ff8df1f2e168cdb0a0fb393897dd5df
#   - negative_273.jpg
#   - negative_272.jpg
#
# Hash: a1ea9cc491881c821f4af87c49680778
#   - neutral_142.jpg
#   - neutral_460.jpg
#   - neutral_023.jpg
#
# Hash: ca55250c5d60b07497f97386422088b8
#   - neutral_509.jpeg
#   - neutral_508.jpeg
#
# Hash: eb78fa167a61f9c4492e34a9fd0db67f
#   - negative_349.jpg
#   - negative_348.jpg
#
# Hash: 629cf94c866dfaf4c1e8176e3e7b1271
#   - negative_397.jpeg
#   - negative_396.jpeg
#
# Hash: 59b85b3846a8b5ecaac73abf419d96a7
#   - negative_307.jpeg
#   - negative_306.jpeg
#
# Hash: 20f90f4beca21df5cd9cabc00083d86b
#   - negative_605.jpg
#   - negative_604.jpg
#
# Hash: 3266867b7b82df3ca1a71f361432d2c9
#   - negative_012.jpg
#   - negative_015.jpg
#
# Hash: 8216a7c4187cba075302586263fa2d34
#   - positive_413.jpeg
#   - positive_412.jpeg
#
# Hash: 72333f8f4fac7397b5ad0b7600e2e8e6
#   - negative_294.jpg
#   - negative_295.jpg
#
# Hash: c0b9033fcb4a9ad90e5693787b7dfff5
#   - neutral_488.jpg
#   - neutral_487.jpg
#
# Hash: 2b713869da6d71f248caf640449b7e05
#   - neutral_643.jpeg
#   - neutral_644.jpeg
#
# Hash: 3ffede13bd1f83b1f295c99f042eed01
#   - negative_134.png
#   - negative_595.jpg
#
# Hash: f56f047f84dc7bd17b62b4e04168a8b3
#   - negative_415.jpeg
#   - negative_414.jpeg
#
# Hash: fa9d9e6f04783e2ebdf9875330c2f0c4
#   - neutral_542.jpg
#   - neutral_543.jpg
#
# Hash: 43640f05115ad21f843e723c9f78feca
#   - neutral_404.jpg
#   - neutral_405.jpg
#
# Hash: 4d84841d83ec1aee08c2caa71bb03030
#   - positive_615.jpeg
#   - positive_614.jpeg
#
# Hash: c243a917e8dd8abeed6ed8762fcb9d76
#   - positive_259.jpg
#   - positive_258.jpg
#
# Hash: df997064343254cc60afe1d2a1cd2c26
#   - neutral_003.jpg
#   - neutral_135.jpg
#
# Hash: 2389540a215ef4ed9d7362e871d45289
#   - neutral_571.jpeg
#   - neutral_572.jpeg
#
# Hash: 0cebb42c57092c39a1b428b8eb8511e3
#   - negative_248.jpg
#   - negative_249.jpg
#
# Hash: ce62d5894f301c21aaba25cee3639d0a
#   - neutral_566.jpg
#   - neutral_565.jpg
#
# Hash: 83720a2995a28ee263f65a1535cc80f2
#   - positive_610.jpg
#   - positive_611.jpg
#
# Hash: c7b5b4373ddf0dfeabe7cfac5df34774
#   - neutral_149.jpeg
#   - neutral_147.jpeg
#
# Hash: 5d750a5cb353236d1d8be4d6faf0e170
#   - neutral_368.jpeg
#   - neutral_367.jpeg
#
# Hash: 360e3ffac312e21671a6875840cea470
#   - negative_518.jpg
#   - negative_517.jpg
#
# Hash: 6e7bfe926266124a81042b3ced784b98
#   - positive_526.jpeg
#   - positive_527.jpeg
#
# Hash: fbbcdcda277ba407258efc604da97109
#   - negative_252.jpg
#   - negative_253.jpg
#
# Hash: 7ea3b4006c0f118460c79a3aff4cc119
#   - positive_051.jpeg
#   - positive_108.jpeg
#
# Hash: 238a2cd226999205c27de48f7cfe840a
#   - positive_328.jpg
#   - positive_327.jpg
#
# Hash: 25704fb46ef54253036087f5451e567e
#   - positive_460.jpeg
#   - positive_459.jpeg
#
# Hash: f0072559d6d06d7f45c5ee5a5b7069af
#   - positive_355.jpeg
#   - positive_356.jpeg
#
# Hash: af56c2928a5a2d5a756cf561e70e0be7
#   - positive_565.jpeg
#   - positive_564.jpeg
#
# Hash: 149295b44772e6cc12d393696c152c96
#   - neutral_281.jpeg
#   - neutral_282.jpeg
#
# Hash: db1a15e30e89c33a53158c5c927a31bc
#   - negative_165.jpg
#   - negative_164.jpg
#
# Hash: 78a6b88c67e93b87fcbde1e1d7a1a799
#   - positive_384.jpeg
#   - positive_383.jpeg
#
# Hash: 40992e56e113c8f6b8ab606ceb4c5446
#   - negative_215.jpg
#   - negative_214.jpg
#
# Hash: d1f0c10a4d03bd5980c9cc1d3b313cb6
#   - neutral_456.jpeg
#   - neutral_455.jpeg
#
# Hash: 3b0da1099babd687031d11d7c7c0e545
#   - positive_114.jpeg
#   - positive_115.jpeg
#
# Hash: bc8c768d5adf7f8ac87cf2a8a214533f
#   - negative_610.jpg
#   - negative_611.jpg
#
# Hash: 582f96586722a4e3515b048066b249a4
#   - neutral_422.jpeg
#   - neutral_423.jpeg
#
# Hash: c1d8b437a61b94a17760d0471c74c575
#   - negative_552.jpg
#   - negative_553.jpg
#
# Hash: f66c8e3df45091f4eab8d17eef2f701f
#   - positive_016.jpeg
#   - positive_018.jpeg
#
# Hash: 6958877d55fbd0eb6c8eb89708f037f5
#   - neutral_510.jpg
#   - neutral_511.jpg
#
# Hash: c802604e00e55ecfd135763ba1abc51f
#   - neutral_342.jpg
#   - neutral_341.jpg
#
# Hash: 82bcc392c3ddbbf48a20cfd1afad73e6
#   - negative_520.jpeg
#   - negative_519.jpeg
#
# Hash: 45ada3540074d5b57d779a694eab2830
#   - neutral_162.jpeg
#   - neutral_618.jpeg
#
# Hash: da8f3db232c42ca25eaa64b0a0c860f5
#   - neutral_602.jpg
#   - neutral_603.jpg
#
# Hash: fba5d35838edbe64b4bd33f90e742f4b
#   - negative_500.jpeg
#   - negative_499.jpeg
#
# Hash: a22cb73b50216dfc982563e5d43f2109
#   - negative_337.jpeg
#   - negative_336.jpeg
#
# Hash: 622d9ccb31467c887454662e8c55e45a
#   - negative_286.jpeg
#   - negative_287.jpeg
#
# Hash: 9ea9878edae7fea5008278f9cce17ad7
#   - neutral_562.jpg
#   - neutral_561.jpg
#
# Hash: 32b8a7643f38223186839f89ab31d124
#   - positive_265.jpg
#   - positive_266.jpg
#
# Hash: 8f8a6a796dd0d4f2d04e904da0e7f361
#   - negative_270.jpg
#   - negative_271.jpg
#
# Hash: fedddecb2baa861d542aac7eaa1c57af
#   - negative_473.jpeg
#   - negative_472.jpeg
#
# Hash: 71384da41285d72f216920a3e0a5ae29
#   - negative_322.jpeg
#   - negative_323.jpeg
#
# Hash: 4c055510787905fd5ec3e373fd4e37ac
#   - negative_329.jpeg
#   - negative_328.jpeg
#
# Hash: d7ab9f8aa0273eb1c19567fb188eb9a1
#   - positive_550.jpeg
#   - positive_549.jpeg
#
# Hash: 2046f92631ee40f118656d4c0bdfe401
#   - neutral_168.jpg
#   - neutral_167.jpg
#
# Hash: 686d18d8e72f7bb144451734390eeff3
#   - positive_522.jpeg
#   - positive_523.jpeg
#
# Hash: 24c18a8ee60b21f89ada8491678e07fc
#   - positive_952.jpg
#   - positive_741.jpg
#
# Hash: 375c802d5db08af2f0c1710d1dafc04a
#   - positive_101.jpg
#   - positive_451.jpg
#   - positive_452.jpg
#
# Hash: 2c2e75f0b5d939b61f8c57b42c1a86ae
#   - negative_078.jpeg
#   - negative_079.jpeg
#
# Hash: 301a38a33e02c1ea1d87949966c4239a
#   - negative_494.png
#   - negative_493.png
#
# Hash: 41d23babb54508dcf32fee03ca8ef568
#   - positive_316.png
#   - positive_315.png
#
# Hash: 564137117932b36953e1a2e01dfbc687
#   - neutral_134.jpg
#   - neutral_133.jpg
#
# Hash: 987898b96d529df79461ccd17e393fe8
#   - neutral_544.jpeg
#   - neutral_545.jpeg
#
# Hash: 1c336e1b8de151361d39eb20e11fa43a
#   - negative_549.jpg
#   - negative_550.jpg
#
# Hash: 673574fc88943f9488919d841472715a
#   - positive_612.jpg
#   - positive_613.jpg
#
# Hash: 06ff4a5aeb55a03c7662abe319b9c359
#   - negative_269.jpg
#   - negative_268.jpg
#
# Hash: fce1b144155d8315e1635880a64f153c
#   - negative_465.jpeg
#   - negative_464.jpeg
#
# Hash: 11134da32cbfa45fe9a74bf7ee1b924d
#   - positive_494.jpeg
#   - positive_493.jpeg
#
# Hash: f4e43104235e842012984c6ebb9c5e20
#   - neutral_637.jpeg
#   - neutral_638.jpeg
#
# Hash: 8576323cf49e58bbf69af1ab772a2561
#   - neutral_373.jpg
#   - neutral_372.jpg
#
# Hash: 27b0dc3c90e4e29a21d4c1fc2f76392b
#   - neutral_320.jpg
#   - neutral_319.jpg
#
# Hash: 038f94d9ca13109fd0381e7ac60bb599
#   - neutral_501.jpeg
#   - neutral_500.jpeg
#
# Hash: 896c0491ec6f14c079d90f6601ebaa0b
#   - neutral_137.png
#   - neutral_136.png
#
# Hash: 34ac8ab32f0033551eb56092c303a0c2
#   - negative_503.jpg
#   - negative_504.jpg
#
# Hash: f2a152d15bd7d31e3d50bf6f23b344a9
#   - negative_484.jpg
#   - negative_485.jpg
#
# Hash: 1e7238d68aae5c839ac2819d85e38aa6
#   - positive_299.jpeg
#   - positive_300.jpeg
#
# Hash: 6687e062743f41ff734ab6bb51604e0c
#   - positive_386.jpeg
#   - positive_385.jpeg
#
# Hash: 8dec9c0caa8be0d42553317c0eb3fd97
#   - negative_021.jpeg
#   - negative_023.jpeg
#
# Hash: 240e1a94aaad7fc582e9613a3db43a81
#   - negative_049.jpg
#   - negative_582.jpg
#
# Hash: e4714f6f64a05064cdaa670a50f3decd
#   - negative_502.jpg
#   - negative_501.jpg
#
# Hash: 0081a5d3c7521e37ad3608b5dd908ca5
#   - positive_196.jpeg
#   - positive_195.jpeg
#
# Hash: 08bacd4490f1beeeee2fa26884e4f477
#   - positive_492.jpg
#   - positive_491.jpg
#
# Hash: 2ce70db2e4020cd337e1c6d0db479542
#   - negative_246.jpg
#   - negative_247.jpg
#
# Hash: 6a00302458cce56d652a777e2b77aad6
#   - neutral_360.jpeg
#   - neutral_359.jpeg
#
# Hash: 0f8c5355fa7d3a4d0bbaa91988b68cd3
#   - neutral_217.jpeg
#   - neutral_216.jpeg
#
# Hash: 55b5917750b0c8c907ffe955624ca488
#   - positive_573.jpeg
#   - positive_572.jpeg
#
# Hash: b9dd8d473e31a93448553c52299e7eef
#   - positive_333.jpeg
#   - positive_334.jpeg
#
# Hash: 6e2bd6ede5c282e944d24823668f7fcf
#   - positive_595.jpeg
#   - positive_596.jpeg
#
# Hash: df3c9d9d03af2a41f122472bf73be167
#   - positive_274.jpg
#   - positive_273.jpg
#
# Hash: 88d13b08933f9d7966e4372159aa4f9b
#   - positive_518.jpeg
#   - positive_519.jpeg
#
# Hash: 7ad421f62dd095839d42636adb5ebe87
#   - neutral_291.jpg
#   - neutral_292.jpg
#
# Hash: 78bd342a67e3b847810169bcc60c9491
#   - positive_121.jpg
#   - positive_465.jpg
#
# Hash: 5184ff596ffd48b86d3e7969f5d24576
#   - negative_542.jpeg
#   - negative_543.jpeg
#
# Hash: cbff3a3b83c3794b43e88255224d114a
#   - positive_576.jpeg
#   - positive_577.jpeg
#
# Hash: 154e68c05cc268a8a4fe894a5d720942
#   - positive_117.jpg
#   - positive_461.jpg
#   - positive_462.jpg
#
# Hash: 5b04c0a15b75991abd9e1ecae5cef919
#   - negative_304.jpeg
#   - negative_305.jpeg
#
# Hash: 6d96071a5aa80e3c0cb4bb3f2037b077
#   - positive_127.jpeg
#   - positive_126.jpeg
#
# Hash: b530a85365258387bac60b4492d6eda9
#   - neutral_246.jpeg
#   - neutral_245.jpeg
#
# Hash: 0084d598e1fe0f8f33f447817f3a27d9
#   - positive_365.jpeg
#   - positive_366.jpeg
#
# Hash: adcae4544c53c5db5eaa081a04c0e18c
#   - positive_411.png
#   - positive_410.png
#
# Hash: 578bf03ff53bea8f888d6ab252281f5c
#   - negative_035.jpg
#   - negative_032.jpg
#
# Hash: c83cfa5df6cf6d3562692464673878d2
#   - positive_473.jpg
#   - positive_472.jpg
#   - positive_129.jpg
#
# Hash: b7853f9f3ee4b97fc4f8dc3366edc3f0
#   - neutral_171.jpeg
#   - neutral_172.jpeg
#
# Hash: 50b4798b71cb278c5cc3d875c8d8a21d
#   - negative_403.jpeg
#   - negative_402.jpeg
#
# Hash: 42ff45e13bb97a17c13ac6d592b4dca2
#   - positive_122.jpeg
#   - positive_123.jpeg
#
# Hash: f2ef2372b467c419fd8b348e15e63e5a
#   - negative_175.jpg
#   - negative_174.jpg
#
# Hash: ed1ceeb29614806e7279b0a55ad77e20
#   - neutral_537.jpeg
#   - neutral_536.jpeg
#
# Hash: 2dab1cd0d905bcc4000de0eb98eba5de
#   - neutral_264.jpg
#   - neutral_265.jpg
#
# Hash: 7514c78cfbce6934912ed5e738597bad
#   - negative_007.jpg
#   - negative_010.jpg
#
# Hash: be64b729617c2730c40d986fd63b9351
#   - neutral_512.jpeg
#   - neutral_513.jpeg
#
# Hash: 5a7b5f417cf52fd4ec33150e1022fc90
#   - negative_264.jpg
#   - negative_265.jpg
#
# Hash: 09fdd2ee07839466c01ce2aad1c2e530
#   - negative_075.png
#   - negative_074.png
#
# Hash: 3b49b6551cdc10fbd2925d805c2019a2
#   - negative_341.jpeg
#   - negative_340.jpeg
#
# Hash: 3d214e7d6952b732a48ebed06c14f17e
#   - positive_507.jpg
#   - positive_508.jpg
#
# Hash: dec4e1874112eeec58973253d0bc7f5f
#   - neutral_425.jpg
#   - neutral_424.jpg
#
# Hash: 0581aa4f7427191556cbe5e1dacb200a
#   - positive_405.jpeg
#   - positive_404.jpeg
#
# Hash: f1b838a90325b635db4d98017c7d5484
#   - neutral_257.jpeg
#   - neutral_256.jpeg
#
# Hash: 38a4b94537045251ba75023e50f84625
#   - negative_433.jpg
#   - negative_434.jpg
#
# Hash: 6b26ac3f70f7dc197099d138fc5f7208
#   - positive_242.jpg
#   - positive_243.jpg
#
# Hash: 84b84761cf850e9e012b15d7755521f8
#   - positive_407.jpeg
#   - positive_406.jpeg
#
# Hash: 343547f729a75d9b7cd5a090ecbf3e52
#   - positive_294.jpeg
#   - positive_293.jpeg
#
# Hash: 5046ef91ef6d77685f67a4840cf1afad
#   - positive_285.jpg
#   - positive_286.jpg
#
# Hash: 00e00dd4406578df3171222a77794e05
#   - neutral_181.png
#   - neutral_180.png
#
# Hash: ddbd7deec1f79a0ab873476b95dfa40a
#   - neutral_595.jpg
#   - neutral_030.jpg
#   - neutral_027.jpg
#
# Hash: 293cfdb4f3cb39522e9867315f0c68f0
#   - negative_344.jpeg
#   - negative_345.jpeg
#
# Hash: 0b0ca111efc8f4472c06fee5ca96ead1
#   - negative_327.jpeg
#   - negative_382.jpeg
#   - negative_326.jpeg
#   - negative_383.jpeg
#
# Hash: 6b6db0f2dbebd7f801e7d520ea17fbc8
#   - negative_458.jpeg
#   - negative_459.jpeg
#
# Hash: 68a177ce09e5b4063f3816326b2216f2
#   - neutral_531.jpg
#   - neutral_530.jpg
#
# Hash: df55ae16cf45ee083d98ba9eb4100c1b
#   - positive_341.jpeg
#   - positive_342.jpeg
#
# Hash: ecad830341b907c52c9e55f224043839
#   - neutral_541.jpeg
#   - neutral_540.jpeg
#
# Hash: cc46eaea07fbb3e85e941ec400c74262
#   - positive_368.jpeg
#   - positive_367.jpeg
#
# Hash: db338836b4a11df426b977034f4718b1
#   - positive_138.jpeg
#   - positive_140.jpeg
#
# Hash: 60c2e9e85846cbb0a7c179a2735a109b
#   - negative_105.jpg
#   - negative_107.jpg
#
# Hash: 20514d947cf190b7cf13ca0af2607fea
#   - negative_145.jpg
#   - negative_147.jpg
#
# Hash: 106746b2cbcb70f58735618a66d660a8
#   - neutral_391.jpeg
#   - neutral_390.jpeg
#
# Hash: dede6db933e3404294c39e50a676b8c8
#   - negative_416.jpg
#   - negative_417.jpg
#
# Hash: 75fa9db94a08f27d3976ebb1a415a623
#   - neutral_393.jpg
#   - neutral_392.jpg
#
# Hash: 1e129b5ff276e66cc7b1b1aceb1772c3
#   - neutral_473.jpeg
#   - neutral_474.jpeg
#
# Hash: 095d6dd04c2f060839607947ad9df77f
#   - neutral_387.jpeg
#   - neutral_386.jpeg
#
# Hash: 0cd0e79e4f65e362276d6b1150ac5f36
#   - negative_466.jpeg
#   - negative_467.jpeg
#
# Hash: 73057950f4053f69fd8a00da8db1650e
#   - negative_521.jpeg
#   - negative_522.jpeg
#
# Hash: 9324211a17e886fb6b24e27e4d7d92fe
#   - negative_614.jpg
#   - negative_613.jpg
#
# Hash: 626d0d8b3f4df47d632dae053be9311c
#   - positive_095.jpeg
#   - positive_094.jpeg
#
# Hash: 638f81868951141f750c11e38a028422
#   - positive_179.jpeg
#   - positive_180.jpeg
#
# Hash: db98e6fe0d10a0ad77fc51d355e115c1
#   - neutral_164.png
#   - neutral_163.png
#
# Hash: b567719df6ec0252841a5307abaf13bd
#   - neutral_524.jpeg
#   - neutral_525.jpeg
#
# Hash: cade1ba346b3697f47124f5a7a1c04bd
#   - negative_438.jpeg
#   - negative_437.jpeg
#
# Hash: 01ac573815875d641b0300bdbdcdf405
#   - neutral_517.jpeg
#   - neutral_516.jpeg
#
# Hash: 545bc185c3d27c84faee32caa948519e
#   - positive_007.jpeg
#   - positive_936.jpeg
#
# Hash: 7197759303da5178d91e4af97a57ac74
#   - negative_238.jpg
#   - negative_239.jpg
#
# Hash: c316135f1e77fc34958f56fea055d722
#   - positive_456.jpeg
#   - positive_457.jpeg
#
# Hash: 0954edbd70eabcd2287870865c8adb1c
#   - neutral_384.jpg
#   - neutral_385.jpg
#
# Hash: b20cd53bfcfff18f2b900fdeee18210f
#   - neutral_436.jpg
#   - neutral_435.jpg
#
# Hash: 826956262c67634df806cf31c7e54fec
#   - neutral_286.jpeg
#   - neutral_285.jpeg
#
# Hash: 0f97e2a5c34613411808009c4af092c4
#   - negative_408.jpeg
#   - negative_409.jpeg
#
# Hash: 4c6a40ffc1f3a4bc8afb508bc72937af
#   - positive_395.jpeg
#   - positive_394.jpeg
#
# Hash: 8ebdef0fac94bf3a4e20fe03672b280b
#   - neutral_630.jpeg
#   - neutral_629.jpeg
#
# Hash: 3d9b18c851c5cc5ae7bda3f924394de0
#   - neutral_224.jpg
#   - neutral_225.jpg
#
# Hash: 716b80c556859cd4c666643dc717ee35
#   - positive_632.jpg
#   - positive_633.jpg
#
# Hash: 78d4182a77f9532f66f4ba63d9863c79
#   - positive_024.jpeg
#   - positive_022.jpeg
#
# Hash: 4a479352f941c29bde929dd30696bc84
#   - negative_161.jpg
#   - negative_588.jpg
#
# Hash: ace52ec9f8a56803934286918ebe55b7
#   - neutral_318.jpeg
#   - neutral_317.jpeg
#
# Hash: 8314ef0c7c673ec7b7d9d91ca32943b1
#   - negative_191.jpg
#   - negative_190.jpg
#
# Hash: 297f65616abb5f7f4281534570d44787
#   - negative_052.jpg
#   - negative_055.jpg
#
# Hash: 66f696239dfaff62d801681669d64e06
#   - neutral_005.jpg
#   - neutral_574.jpg
#   - neutral_573.jpg
#   - neutral_002.jpg
#
# Hash: 318a695b7d5bf27dd24dcb4d192cfebf
#   - neutral_520.jpeg
#   - neutral_521.jpeg
#
# Hash: 3383c73bea809ac43e7d253fbff69a80
#   - positive_338.jpeg
#   - positive_337.jpeg
#
# Hash: de6ca714e21414e8d783a97da62f700b
#   - positive_605.jpeg
#   - positive_604.jpeg
#
# Hash: 28b4db7682bb4e75ce10de51903f9a70
#   - positive_439.jpg
#   - positive_046.jpg
#   - positive_440.jpg
#
# Hash: 91e36cf1bf1bed2351265be8f9b26974
#   - negative_183.jpg
#   - negative_182.jpg
#
# Hash: 5d44be344ef776f18daa3b241bb37f53
#   - neutral_340.jpeg
#   - neutral_339.jpeg
#
# Hash: 14d2ef66c1beed064855f7087b113497
#   - positive_362.jpeg
#   - positive_361.jpeg
#
# Hash: d294031d1ddee6b39202ff51020bf938
#   - neutral_578.jpg
#   - neutral_010.jpg
#   - neutral_007.jpg
#   - neutral_577.jpg
#
# Hash: 6b9d16ff4136a6dcc9a264f3670f8412
#   - positive_495.jpg
#   - positive_496.jpg
#
# Hash: 76fa4c2234c99be0b9877e91e69fdc80
#   - neutral_609.jpg
#   - neutral_610.jpg
#
# Hash: 3a3ab073c724bea1dd31616d2758035d
#   - positive_105.jpg
#   - positive_455.jpg
#
# Hash: 40fb8d9795cc3f12063f4f1fbd462c78
#   - positive_271.jpg
#   - positive_272.jpg
#
# Hash: 58048848f834106e8365ef631d3001d6
#   - negative_257.jpg
#   - negative_256.jpg
#
# Hash: 3d9c0caf5162a4082f49725e2173d575
#   - negative_454.jpeg
#   - negative_455.jpeg
#
# Hash: c82e18332d9e62bb797c2a26e41d7912
#   - positive_370.jpeg
#   - positive_369.jpeg
#
# Hash: 59d01caac963354823fd3c0eaf3ace90
#   - negative_577.jpg
#   - negative_578.jpg
#
# Hash: e52cc2aeea161a22a880dbb8d6946c17
#   - negative_002.jpg
#   - negative_005.jpg
#
# Hash: c488f2abfed23b2f374c547711eb6842
#   - positive_168.jpg
#   - positive_169.jpg
#
# Hash: 11d0b406975ad9af7e6589e7537a3b73
#   - negative_390.jpeg
#   - negative_391.jpeg
#
# Hash: 7589745b15cd9d493f1e4a7fa7facd84
#   - neutral_131.jpeg
#   - neutral_608.jpeg
#
# Hash: d4bd7c581ff1f37d22437e2d9e17953b
#   - neutral_321.jpeg
#   - neutral_322.jpeg
#
# Hash: 3afca97dd90382b944f6dda9b45b43ba
#   - neutral_579.jpeg
#   - neutral_580.jpeg
#
# Hash: 92dac409eb3d3c7ca427d89a2b48eeaa
#   - positive_080.jpeg
#   - positive_082.jpeg
#
# Hash: 3f5e6fe288e5e53d5de017b97416d18b
#   - negative_903.jpeg
#   - negative_084.jpeg
#
# Hash: aa641106ddde861b5327a49b5f307fe5
#   - positive_314.jpeg
#   - positive_313.jpeg
#
# Hash: abbd61f9b3fb6ff8a6aa67bd56a9b282
#   - positive_343.jpeg
#   - positive_344.jpeg
#
# Hash: 10d54bd63d32f2580382389b4e330dbe
#   - positive_106.jpeg
#   - positive_107.jpeg
#
# Hash: efd63f9de4c3d765ee3559f353d1d6ab
#   - neutral_605.jpeg
#   - neutral_125.jpeg
#   - neutral_604.jpeg
#
# Hash: d61db53c99ebefaee90d09f98752b737
#   - positive_267.jpg
#   - positive_268.jpg
#
# Hash: 8e70acd84dc0ee584154bf423b64c0ef
#   - positive_559.jpeg
#   - positive_558.jpeg
#
# Hash: 4cc330976a1ed764e3ecfd58e3ae9668
#   - neutral_254.jpg
#   - neutral_255.jpg
#
# Hash: 68f77c257803246152a5b874b9224de9
#   - positive_601.jpeg
#   - positive_600.jpeg
#
# Hash: ebca49a57dd924babb34eac141461894
#   - neutral_296.jpg
#   - neutral_295.jpg
#
# Hash: cc74015fd02c7e8793edc20ef450b6e0
#   - positive_176.jpeg
#   - positive_177.jpeg
#
# Hash: e7d34c032e73a204f8addd2ced71093e
#   - positive_165.jpg
#   - positive_163.jpg
#
# Hash: 9dc8a485a8ee78e8fbd85fd936c1485a
#   - neutral_445.jpeg
#   - neutral_444.jpeg
#
# Hash: e3d963ee57f10e1db5d2ff35ae7773c0
#   - positive_408.jpg
#   - positive_409.jpg
#
# Hash: b4a7bd560cd3ce18d1ed302440694f05
#   - negative_199.jpg
#   - negative_198.jpg
#
# Hash: 5df282c762900b7cd0bc74a6caf9b5d3
#   - positive_232.jpeg
#   - positive_231.jpeg
#
# Hash: b0fe34a3ba76897131d511c615e88055
#   - positive_543.jpeg
#   - positive_542.jpeg
#
# Hash: 5ce9bdd0eab569fb45f17bbe7b61f37a
#   - negative_529.jpeg
#   - negative_528.jpeg
#
# Hash: a8d30e780d009185c143d3f041c9054b
#   - positive_737.jpg
#   - positive_769.jpg
#
# Hash: d54f5a04cb9b423f94f7ac811b8e07aa
#   - neutral_300.jpg
#   - neutral_299.jpg
#
# Hash: be95f807f241f7d17e889f6a1d0587b2
#   - neutral_476.jpg
#   - neutral_475.jpg
#
# Hash: 5d87ebc278a156926a808f30e05f0136
#   - negative_150.jpg
#   - negative_148.jpg
#
# Hash: f5f978a04b94dc1e80b54d869b61d853
#   - positive_348.jpeg
#   - positive_347.jpeg
#
# Hash: 01ec2cb80cedc23268b033a7ba5ded62
#   - neutral_278.jpeg
#   - neutral_277.jpeg
#
# Hash: 3da5cdb4ef69424dc99eee2fb3e169b8
#   - positive_324.jpeg
#   - positive_323.jpeg
#
# Hash: 6eea87d7e73fa04c11f967112221e706
#   - positive_052.jpg
#   - positive_443.jpg
#   - positive_444.jpg
#
# Hash: ea8fdfc053bd691ae335b683c231eda7
#   - negative_045.jpg
#   - negative_042.jpg
#
# Hash: 84311c19c546d6efe42d000e5f521caf
#   - negative_288.jpeg
#   - negative_289.jpeg
#
# Hash: d2ee4c40ba48a796994436efb8fb83c2
#   - negative_430.jpeg
#   - negative_431.jpeg
#
# Hash: 3b349b66276311c70611d7b4fcb2584c
#   - neutral_555.jpeg
#   - neutral_556.jpeg
#
# Hash: ed7ea0c4d7d65d0853ff1c0ce4afe67f
#   - neutral_533.jpeg
#   - neutral_532.jpeg
#
# Hash: ba97b02ddfa451f267907983e74d5332
#   - negative_339.jpeg
#   - negative_135.jpeg
#   - negative_338.jpeg
#   - negative_132.jpeg
#
# Hash: 5a1b6814c8a74af7e06ad75491aae0f8
#   - positive_448.jpg
#   - positive_072.jpg
#   - positive_447.jpg
#
# Hash: 0cf2fcb897de4f5309963eb4a94470e0
#   - neutral_434.jpeg
#   - neutral_433.jpeg
#
# Hash: 7fde374b5a2b815757a162e277e7e555
#   - neutral_251.jpg
#   - neutral_250.jpg
#
# Hash: 4e79790a260785f346c93c0ad96ee73b
#   - positive_397.jpeg
#   - positive_398.jpeg
#
# Hash: a27715e8ed8ed812eea063d738689025
#   - neutral_498.jpg
#   - neutral_499.jpg
#
# Hash: 726caabd909bd7572dab591f074aa6a7
#   - neutral_458.jpeg
#   - neutral_459.jpeg
#
# Hash: 9f825ddcef20b7aa38722371e7fb1e6a
#   - negative_267.jpg
#   - negative_266.jpg
#
# Hash: ff878c000c19bbacecc01a4a65243867
#   - positive_346.jpeg
#   - positive_345.jpeg
#
# Hash: f8588cc97ecaab195cefd6cea7dfeb73
#   - neutral_383.jpeg
#   - neutral_382.jpeg
#
# Hash: 77481f313e955157d95e6e276537767b
#   - positive_433.jpg
#   - positive_432.jpg
#   - positive_032.jpg
#
# Hash: 04b9d9ea543fdd2527bd6d74c6d05d6a
#   - negative_371.jpg
#   - negative_370.jpg
#
# Hash: 8ffda0a1efd9fe95d461dc824e21b143
#   - neutral_310.jpeg
#   - neutral_309.jpeg
#
# Hash: 60186c94a0939d112d57913965cd7cfb
#   - positive_350.jpg
#   - positive_349.jpg
#
# Hash: 359309f75884e0e39c3db94a4fcd9eb2
#   - neutral_633.jpeg
#   - neutral_634.jpeg
#
# Hash: 032937f7039d121e305343c2b717185c
#   - neutral_263.jpeg
#   - neutral_262.jpeg
#
# Hash: 3e4006628ff2f74738a243f74e509d69
#   - positive_530.jpeg
#   - positive_529.jpeg
#
# Hash: 37e319066c238da8cbc0195477bcdd12
#   - positive_004.jpeg
#   - positive_006.jpeg
#
# Hash: 7d0c9f1dec141c657568160516b52576
#   - positive_503.jpeg
#   - positive_502.jpeg
#
# Hash: 9b5843ae2dcdf1da09306f90e06e867a
#   - positive_152.jpeg
#   - positive_154.jpeg
#
# Hash: 4e4f7bee731de9a7dd947a059a497e14
#   - positive_421.jpg
#   - positive_420.jpg
#
# Hash: a3a4e95e83b51ad176dee5f82bd106b9
#   - neutral_215.png
#   - neutral_214.png
#
# Hash: 1470f41fd1dd4781d5d06fdd7330cb8e
#   - neutral_401.jpg
#   - neutral_400.jpg
#
# Hash: b01361be539219d7314340f79d953f3e
#   - negative_020.jpg
#   - negative_017.jpg
#
# Hash: a969972f0c0c37574abeda4d7750f907
#   - negative_626.jpg
#   - negative_625.jpg
#
# Hash: 1d8f3c9d99df4a62a8353d178a59fea6
#   - negative_232.jpg
#   - negative_233.jpg
#   - negative_906.jpg
#
# Hash: 7428d7fc77a0b110f57259a4bbf72b4e
#   - neutral_477.jpeg
#   - neutral_478.jpeg
#
# Hash: ef926966e32596f193d8e84191acde14
#   - positive_378.jpeg
#   - positive_377.jpeg
#
# Hash: 3b66427f512e349a97aa6c5a76b8ef64
#   - neutral_122.jpg
#   - neutral_120.jpg
#
# Hash: 7693ca7c4ea110d8e0d1afb8b7d63645
#   - positive_436.jpg
#   - positive_037.jpg
#   - positive_435.jpg
#
# Hash: ef46146e929ef929d6c90153159b586f
#   - neutral_552.jpeg
#   - neutral_553.jpeg
#
# Hash: de62cda86d60438b6652c509cb54fbf0
#   - neutral_567.jpeg
#   - neutral_568.jpeg
#
# Hash: 53867f902caf8fe99ab034082dd89a12
#   - neutral_077.png
#   - neutral_078.png
#
# Hash: 13f238a22fd71b15533081fb0947dc6d
#   - positive_183.jpg
#   - positive_184.jpg
#
# Hash: 72e1e32c23899288a6648a3a79824383
#   - negative_093.jpg
#   - negative_095.jpg
#
# Hash: d625b05581a5cd2c44f6c12741f11119
#   - neutral_347.jpeg
#   - neutral_348.jpeg
#
# Hash: a6200a44f8ff19f1b8f3d90bd360a34f
#   - neutral_535.jpg
#   - neutral_534.jpg
#
# Hash: ef5b62333700968e62b4a678e2dbe844
#   - negative_728.jpg
#   - negative_022.jpg
#   - negative_901.jpg
#
# Hash: 04d93b67c45a556e47a8041b72c63f8b
#   - negative_218.jpg
#   - negative_219.jpg
#
# Hash: aa085af02eebfaa5a081e262ed1b945a
#   - negative_360.jpeg
#   - negative_361.jpeg
#
# Hash: 01eb9684bb5e06b79aa747ad0bd8e105
#   - positive_075.jpeg
#   - positive_077.jpeg
#
# Hash: 61e3e317307ac7fdc8a53cdb787306f9
#   - positive_551.jpeg
#   - positive_552.jpeg
#
# Hash: a883402af873e7802cd0a0339a10f584
#   - neutral_408.jpg
#   - neutral_409.jpg
#
# Hash: f03b9e118655d2d05fd948975bed0ced
#   - negative_335.jpg
#   - negative_334.jpg
#
# Hash: a0357a982001572cc9a3ce591357c229
#   - negative_448.jpeg
#   - negative_447.jpeg
#
# Hash: 7e6493a0ec66bf67e9e227fb87d8f40a
#   - positive_476.jpg
#   - positive_133.jpg
#
# Hash: b2f5835cd2889a34f276d374ff1e55be
#   - neutral_345.jpg
#   - neutral_346.jpg
#
# Hash: 14138715efe30d01cee4e3096466efb5
#   - neutral_062.png
#   - neutral_064.png
#
# Hash: 8fb8889a805d2f65ff1542c823adc63e
#   - positive_109.jpg
#   - positive_458.jpg
#
# Hash: 33c1e842428170d85443a6e44d83a38a
#   - negative_399.jpeg
#   - negative_398.jpeg
#
# Hash: f80ae38cdf85489dc43cdfc93ee6b133
#   - neutral_247.jpg
#   - neutral_248.jpg
#
# Hash: 2545909861507af417c37dc4da5a6166
#   - positive_575.jpeg
#   - positive_574.jpeg
#
# Hash: d8a835efa9a5ca08fd445bcf759d458b
#   - positive_275.jpg
#   - positive_276.jpg
#
# Hash: 58dbe518a80a81cf5a6e3491aee8fc2b
#   - neutral_457.jpg
#   - neutral_018.jpg
#   - neutral_139.jpg
#
# Hash: aeda52467fee91b56fe5a73751afddfb
#   - positive_382.jpeg
#   - positive_381.jpeg
#
# Hash: f7d57eff145c85f229c6df78cb6c51b9
#   - neutral_395.jpeg
#   - neutral_394.jpeg
#
# Hash: 89dee37920dfe890df9993ef3510f9d5
#   - negative_037.jpg
#   - negative_040.jpg
#
# Hash: eda0433cb90f6a54349c7cac49d62b6d
#   - negative_221.jpg
#   - negative_220.jpg
#
# Hash: 0bd4ecf42f2e199e154c3b8412d19a5e
#   - neutral_503.jpg
#   - neutral_502.jpg
#
# Hash: 0238bb7bae7e152d71621c42b72e799d
#   - neutral_466.jpeg
#   - neutral_465.jpeg
#
# Hash: ee9698d477721424cbeea045febaabf9
#   - neutral_336.jpeg
#   - neutral_335.jpeg
#
# Hash: 3466455d96e244d54263704391f01ddd
#   - positive_375.jpeg
#   - positive_376.jpeg
#
# Hash: d133375f9054aa19e6eda48742e089ec
#   - neutral_418.jpeg
#   - neutral_419.jpeg
#
# Hash: 9d9fbabf88270ae8dfa12d191dae8de8
#   - negative_298.jpg
#   - negative_299.jpg
#
# Hash: 05e8706646c97a64b862ef3bf8a2456f
#   - positive_145.jpeg
#   - positive_143.jpeg
#
# Hash: 01be7a7c3164c83b952d1aa2536b693b
#   - neutral_144.jpg
#   - neutral_009.jpg
#   - neutral_052.jpg
#
# Hash: 65ed7367ae715bf599ba35fd07fc7233
#   - positive_160.jpg
#   - positive_162.jpg
#
# Hash: 60da985fd5a0e089f776796a7b6bf78a
#   - negative_302.jpeg
#   - negative_303.jpeg
#
# Hash: 899496ff9fa679aa533815dfa21aca62
#   - positive_964.jpg
#   - positive_727.jpg
#
# Hash: be6b999ecc9d3091a11377bf6e79e481
#   - neutral_194.png
#   - neutral_195.png
#
# Hash: 107824311c211fa6c704364dfc166dc2
#   - positive_047.jpg
#   - positive_043.jpg
#
# Hash: ff8aa690db3607fc59ce7c6a4eb5e1d5
#   - positive_119.jpeg
#   - positive_118.jpeg
#
# Hash: f3cfe1cd15ee10fb114e58623199ce80
#   - neutral_615.jpeg
#   - neutral_159.jpeg
#   - neutral_614.jpeg
#
# Hash: cfcff797a59760cfe401000afb1b6018
#   - positive_631.jpg
#   - positive_630.jpg
#
# Hash: 690b811f6160c058e1689d54342d622c
#   - negative_510.jpeg
#   - negative_511.jpeg
#
# Hash: d27f202b64c6430a482ad0af87703dfc
#   - negative_179.jpg
#   - negative_178.jpg
#
# Hash: 16fc715ee2a70a05d464f3c0559949ed
#   - negative_151.jpeg
#   - negative_153.jpeg
#
# Hash: 9eaf8dcbbc19ba714989e7bfa7fd7f5a
#   - negative_308.jpg
#   - negative_309.jpg
#
# Hash: bdc09a3549d12d5c89b8a1bf9831b342
#   - positive_500.jpeg
#   - positive_499.jpeg
#
# Hash: 8658713523caccb2dea514d816462a24
#   - negative_384.jpeg
#   - negative_385.jpeg
#
# Hash: 50d6d6ead2d74e25a27f55f967507cbe
#   - neutral_074.jpg
#   - neutral_070.jpg
#
# Hash: 2627d4ee3e0f847161c1109b69c26856
#   - neutral_606.jpg
#   - neutral_035.jpg
#   - neutral_032.jpg
#   - neutral_607.jpg
#
# Hash: 376de2203ebc885d6edd19f5874d9b5a
#   - negative_631.jpeg
#   - negative_632.jpeg
#
# Hash: d2b3a55fbff2a897774a710b72bd2d5f
#   - neutral_124.png
#   - neutral_112.png
#   - neutral_126.png
#   - neutral_114.png
#
# Hash: eff99e8da3a414f624530a858f18e861
#   - negative_200.jpg
#   - negative_201.jpg
#
# Hash: d34212994d1d57757485d775722c71e6
#   - positive_547.jpeg
#   - positive_548.jpeg
#
# Hash: 8058e1e702a3f6fb7e6c27a48ca31896
#   - positive_282.jpg
#   - positive_281.jpg
#
# Hash: 583b37907ee46cc5aff5c1f1cfae5c51
#   - positive_400.jpeg
#   - positive_399.jpeg
#
# Hash: fd33f50b742c71bc6231182b2992fecf
#   - negative_301.jpg
#   - negative_300.jpg
#
# Hash: 249b5fa182f50312b28a531d7b30f735
#   - positive_726.jpg
#   - positive_966.jpg
#
# Hash: c65f19fa946d9242856139cb95aba511
#   - negative_497.jpg
#   - negative_496.jpg
#
# Hash: fac75eb74b2a44a77e0026357c3fd3fe
#   - neutral_641.jpeg
#   - neutral_642.jpeg
#
# Hash: 4568873989c16bb06d0861630e3b292c
#   - positive_545.jpeg
#   - positive_544.jpeg
#
# Hash: 91eaa54204a949a2f12b42ba422cfea6
#   - positive_157.jpeg
#   - positive_155.jpeg
#
# Hash: 7eadf3d5babde545a95b01fcea7f77b9
#   - positive_403.jpeg
#   - positive_402.jpeg
#
# Hash: f4ed61ee8bf1fa72b3de2acca72ffd20
#   - positive_200.jpeg
#   - positive_199.jpeg
#
# Hash: 045400b88448567c843796b976058385
#   - negative_463.jpg
#   - negative_462.jpg
#
# Hash: 1ea02baf4f0feb4eeea7871e42422da3
#   - positive_540.jpeg
#   - positive_539.jpeg
#
# Hash: 96d148b61c7f070ce4afcc36a7b2b809
#   - positive_130.jpeg
#   - positive_131.jpeg
#
# Hash: e9164f0944605b3428bf91bf75d06ddd
#   - positive_516.jpeg
#   - positive_517.jpeg
#
# Hash: 29ac1f03abe53877b19692f539886c1b
#   - negative_562.jpg
#   - negative_561.jpg
#
# Hash: 378695aa22ae449245c6f0180633545e
#   - negative_609.jpg
#   - negative_608.jpg
#
# Hash: 3c2b82610a83af2b31ac7f528fb206aa
#   - negative_441.jpg
#   - negative_442.jpg
#
# Hash: ab75bc3bf651c77b9f0cd80cb16ab26a
#   - positive_197.png
#   - positive_198.png
#
# Hash: 06a759cdba1326f0ce96f8f6a5cb6fba
#   - neutral_260.jpeg
#   - neutral_259.jpeg
#
# Hash: f7963f544dbbaee7b9eee4b0945c6f8b
#   - neutral_082.jpeg
#   - neutral_081.jpeg
#
# Hash: 92a7f425edfa8b5a191084639cbb84b2
#   - positive_053.jpg
#   - positive_049.jpg
#
# Hash: da9f97bc16ac608ef636d916d2db806a
#   - neutral_188.jpg
#   - neutral_189.jpg
#
# Hash: e121186b754c5555e0e6de25f6469bbf
#   - negative_223.jpg
#   - negative_222.jpg
#
# Hash: f68281b316aa35d170dafb726cfbf9a4
#   - negative_350.jpg
#   - negative_351.jpg
#
# Hash: c3bf925a4616b9ad77efe4dc845f1b3d
#   - negative_481.jpg
#   - negative_482.jpg
#
# Hash: cb72fbf6efda54b28bfb407b9d738e47
#   - positive_068.jpg
#   - positive_065.jpg
#
# Hash: 34ef209426a0d6c65207253ce4948edc
#   - negative_359.jpeg
#   - negative_358.jpeg
#
# Hash: 8ce7d14d8a7182d9acfb9140f9865921
#   - neutral_635.jpg
#   - neutral_636.jpg
#
# Hash: 69a9fb20631822f06697cc29acc29b12
#   - positive_149.jpeg
#   - positive_151.jpeg
#
# Hash: 4ca24e56191af701b8756a644333692f
#   - positive_210.jpg
#   - positive_209.jpg
#
# Hash: e7a2f7b520aed15d5d2e1075dd31e9a0
#   - negative_166.jpg
#   - negative_167.jpg
#
# Hash: 28373356de318591138f4003499d8101
#   - neutral_204.png
#   - neutral_203.png
#
# Hash: 1df75fa1a6b1f74ad69150ba67588ad7
#   - neutral_462.jpeg
#   - neutral_461.jpeg
#
# Hash: ebd4577363518416155718eef2c086db
#   - neutral_451.jpeg
#   - neutral_452.jpeg
#
# Hash: 20c0284a1a7a4a36f65dd64306fe7126
#   - positive_214.jpeg
#   - positive_213.jpeg
#
# Hash: b8fba26cb9f96570b8df012b432868b4
#   - positive_571.jpeg
#   - positive_570.jpeg
#
# Hash: 0904a55775801870a6376b73ba86bc5d
#   - negative_375.jpeg
#   - negative_374.jpeg
#
# Hash: 4f4e90fa4d60006508a244d11c5d0dc7
#   - negative_259.jpg
#   - negative_258.jpg
#
# Hash: 635f39ac88678b3041693e988aea1fff
#   - positive_287.jpg
#   - positive_288.jpg
#
# Hash: 43ff95d9f4d0236905e008eb234d5c9c
#   - negative_445.jpg
#   - negative_446.jpg
#
# Hash: 3a4bc23756cf0454be8d5ce0820b97b2
#   - neutral_361.jpg
#   - neutral_362.jpg
#
# Hash: d05b381dbd01209d2444b99c5a662d19
#   - neutral_236.jpg
#   - neutral_235.jpg
#
# Hash: c12c5f9e4302b811ff4da1d28f032e78
#   - positive_290.jpeg
#   - positive_289.jpeg
#
# Hash: 3be2910eec27aed0aadc9881a30b2c98
#   - positive_467.jpeg
#   - positive_466.jpeg
#
# Hash: 9c61a5b27b677bb0f7be48d62724ae5d
#   - positive_104.jpeg
#   - positive_005.jpeg
#
# Hash: 34954369d2d170f352b0184870809cc2
#   - positive_235.jpeg
#   - positive_236.jpeg
#
# Hash: c3dbe7e625af05def44faf893ac48106
#   - neutral_358.jpg
#   - neutral_357.jpg
#
# Hash: bd899b6ed49ddca40c7bfa82da1506e3
#   - positive_305.jpeg
#   - positive_306.jpeg
#
# Hash: f0159ccdeb234996342c86de401d7022
#   - positive_173.jpeg
#   - positive_172.jpeg
#
# Hash: c6d0840d58c6dbf03bb59dd22b468ae1
#   - negative_538.jpeg
#   - negative_537.jpeg
#
# Hash: efdfb9ab35673eb3142d84ef5fa0c5d6
#   - neutral_090.png
#   - neutral_089.png
#
# Hash: 245c66d785d45b9a76fb2f9cf222973b
#   - negative_436.jpeg
#   - negative_435.jpeg
#
# Hash: 7cd01339383a451c5e5ccc1b3908d36a
#   - positive_220.jpeg
#   - positive_219.jpeg
#
# Hash: 1346ec0823fb5c938d63cea412eeeb8d
#   - neutral_046.jpg
#   - neutral_050.jpg
#
# Hash: 85b5b7d2bb0ac25995a5433b13fda182
#   - negative_099.jpg
#   - negative_097.jpg
#
# Hash: 4e7b6e2775db58fc5820b4df5f5ce9e5
#   - negative_236.jpg
#   - negative_237.jpg
#
# Hash: 1c3c2c8fd0d094a18533da1179d1c3da
#   - positive_387.jpeg
#   - positive_388.jpeg
#
# Hash: a1cd1ab913c35d285fd9d8d83bee44fb
#   - positive_026.jpg
#   - positive_430.jpg
#
# Hash: 8a1bf0c9ebffa04a7dde403176c36402
#   - negative_209.jpeg
#   - negative_208.jpeg
#
# Hash: ee921c7dfaf71b60d5bb3a7f4f1e5df2
#   - neutral_207.jpg
#   - neutral_174.jpg
#   - neutral_206.jpg
#   - neutral_173.jpg
#
# Hash: 0c841e5e4cb6e55708d2383a90ffcf28
#   - negative_618.jpg
#   - negative_617.jpg
#
# Hash: a7b41d31ae36f00383968e9676257a6e
#   - negative_057.jpg
#   - negative_060.jpg
#
# Hash: b323632bc65b8763d58a3bc6aa8753d6
#   - negative_274.jpg
#   - negative_275.jpg
#
# Hash: 673ab377519214951a31152d99d67df0
#   - positive_415.jpg
#   - positive_414.jpg
#
# Hash: 8cf05d6edb5a85ecd961480bceb32301
#   - positive_227.jpeg
#   - positive_228.jpeg
#
# Hash: 9afb6258971bea690ea528b39383f251
#   - negative_606.jpg
#   - negative_607.jpg
#
# Hash: 045e2514d46594f629009ca607a42fd3
#   - negative_387.jpeg
#   - negative_386.jpeg
#
# Hash: ce6fb08698fc77336077345a31c3c1e9
#   - neutral_156.jpeg
#   - neutral_158.jpeg
#
# Hash: 22e875474d47aeff88d5201dffc456b2
#   - positive_229.jpeg
#   - positive_230.jpeg
#
# Hash: cdfcfda4bf5fb34830c66b4c3a6199d5
#   - neutral_453.jpg
#   - neutral_454.jpg
#   - neutral_088.jpg
#
# Hash: be08bf941e2e380cc1916e0ff72c32f8
#   - neutral_059.jpg
#   - neutral_056.jpg
#
# Hash: 20cc13cfbb27b3786f7319dde22b40a6
#   - neutral_334.jpg
#   - neutral_333.jpg
#
# Hash: f97795dcb5e2e62b9646c3e7fb916a67
#   - negative_311.jpg
#   - negative_310.jpg
#
# Hash: 0dae46cefd4b7ea2413613d036a93d47
#   - positive_628.jpg
#   - positive_629.jpg
#
# Hash: e2ff6773e34a0992e2483f67639819f7
#   - neutral_221.png
#   - neutral_220.png
#
# Hash: 0df36a96af51aa06d8d78f6e47f90628
#   - positive_175.jpeg
#   - positive_174.jpeg
#
# Hash: ebb00a46abf7be8053d0f5237de87966
#   - neutral_446.jpg
#   - neutral_447.jpg
#
# Hash: 0030cc9c82d1ab6eb1c6f05752e96f02
#   - positive_560.jpeg
#   - positive_561.jpeg
#
# Hash: 4ad357b0fc7989f34d01d41ded1b9f28
#   - neutral_004.jpg
#   - neutral_048.jpg
#
# Hash: 96435e512e673079f6c8f283da4484cb
#   - neutral_627.jpg
#   - neutral_628.jpg
#
# Hash: 67d7c8c62538319b48ae551008cdf9d6
#   - neutral_538.jpg
#   - neutral_539.jpg
#
# Hash: 82a6bdd40bf7a2c08445c24bcecc3482
#   - negative_050.jpg
#   - negative_047.jpg
#
# Hash: 2d75da443466346cf7ab49a5e420ae17
#   - positive_427.jpg
#   - positive_426.jpg
#
# Hash: 19f9838ae398afcd5e9900a7f096327c
#   - neutral_601.jpeg
#   - neutral_600.jpeg
#   - neutral_113.jpeg
#
# Hash: ffde3fdbfdb5f140380084c2f72687b1
#   - positive_279.jpg
#   - positive_280.jpg
#
# Hash: 789938d9b9f89df4c6d9e51df5bd1125
#   - neutral_479.jpg
#   - neutral_480.jpg
#
# Hash: 6035217dd6b855a078a39cd5b4dcf989
#   - positive_110.jpeg
#   - positive_111.jpeg
#
# Hash: f552bd30d7d4c176355d273749419e37
#   - positive_215.jpeg
#   - positive_216.jpeg
#
# Hash: 0365f4aa1269a78d73915591ffe4d072
#   - negative_193.jpeg
#   - negative_192.jpeg
#
# Hash: 1583ddd1b99659f927614add7e814e7e
#   - positive_063.jpg
#   - positive_060.jpg
#
# Hash: 110fd41803751c48fe2925f27f66f453
#   - positive_030.jpeg
#   - positive_028.jpeg
#
# Hash: 0d335396e16ddc973194b30fc10d7c6d
#   - negative_180.jpg
#   - negative_181.jpg
#
# Hash: 50aa4dc23353713cc595c9fdb0812f5d
#   - neutral_304.jpg
#   - neutral_303.jpg
#
# Hash: 1b98d68e3b6451de6a08ccbef09773a3
#   - neutral_597.jpeg
#   - neutral_596.jpeg
#
# Hash: 07e88f102352fdc236a4e49fb00ac900
#   - neutral_141.jpg
#   - neutral_143.jpg
#
# Hash: 5c460439241921457866a45461bdac30
#   - negative_583.jpg
#   - negative_114.jpg
#
# ...
#   - positive_379.jpeg
#
# Hash: 67ab8f89083d467245932dcee0094e18
#   - negative_138.jpg
#   - negative_136.jpg
#
# Hash: 26aafc93cc0f5b40d55bd8f1ce045235
#   - negative_111.jpg
#   - negative_109.jpg
#
# Hash: 88f746c8e580a9a80b75c2d4b95d5b61
#   - positive_186.jpg
#   - positive_185.jpg
#
# Hash: 5e6e590aa23ad640184ee83a25812a41
#   - neutral_464.jpg
#   - neutral_463.jpg
#
# Hash: b2e79d45c4b96c99bc04c11feb192131
#   - positive_424.jpeg
#   - positive_425.jpeg
#
# Hash: 97962d2012c5cb77d6a7ef59d46bee83
#   - negative_126.jpeg
#   - negative_127.jpeg
#
# Hash: b7cf07d46c12c3db942e03a2a824ad15
#   - negative_451.jpeg
#   - negative_450.jpeg
#
# Hash: b7caa352279f611d99fab086adb961af
#   - negative_627.jpg
#   - negative_628.jpg
#
# Hash: a4701b01bc033363433f5e673b69d762
#   - negative_243.jpg
#   - negative_242.jpg
#
# Hash: 85d6f506e9ec355d1ac0d6e39d9d75ff
#   - positive_260.jpg
#   - positive_261.jpg
#
# Hash: 21f4d3befcc0542cd46136252d1c5368
#   - positive_192.jpg
#   - positive_191.jpg
#
# Hash: 5231ebe1a41f341adfd84ff9e5c134f6
#   - neutral_191.png
#   - neutral_190.png
#
# Hash: 12d635a84bc92a9d6903a9653ad3e4e4
#   - negative_560.jpeg
#   - negative_559.jpeg
#
# Hash: af757a4cb5c313ca5ae8330cee05849a
#   - neutral_150.jpg
#   - neutral_152.jpg
#
# Hash: 005304a9ffa70f2329ddd4f7ac1f6154
#   - positive_586.jpeg
#   - positive_585.jpeg
#
# Hash: cab2dac1fbbe3fdad7cda022d47ce4bf
#   - positive_284.jpg
#   - positive_283.jpg
#
# Hash: cfd702feed021ae47604175adfcf2157
#   - neutral_084.jpg
#   - neutral_086.jpg
#
# Hash: ff87e8c5707fccf23ada289a3d38f21f
#   - neutral_351.jpeg
#   - neutral_352.jpeg
#
# Hash: 15e5d4a9f2f6e854802095e9c24a3710
#   - neutral_649.jpeg
#   - neutral_650.jpeg
#
# Hash: a610ca2e1ec1b4b5260d9be3bd8d84fe
#   - positive_321.jpg
#   - positive_322.jpg
#
# Hash: 29b7b9c62510f70e0989bea1a3b203b0
#   - negative_154.jpeg
#   - negative_156.jpeg
#
# Hash: c2d4c1d0f288b34f5a9c1b855a3dea6d
#   - neutral_148.jpg
#   - neutral_061.jpg
#
# Hash: 20e4cead8fcbe6c88e08b0faca3b67a1
#   - positive_233.jpeg
#   - positive_234.jpeg
#
# Hash: 86c8ff848856531fa45969b481f89b49
#   - negative_254.jpg
#   - negative_255.jpg
#
# Hash: 41ad45bbb885c5ce8fcb4c7c7fe6d510
#   - negative_177.jpg
#   - negative_176.jpg
#
# Hash: 2baaebaacc0008a0d406692be607bff1
#   - positive_514.jpeg
#   - positive_515.jpeg
#
# Hash: f2bea94f4a1c44fdec280d64ed8013d8
#   - neutral_226.png
#   - neutral_227.png
#
# Hash: 7a45495f838645f25ea73d6bdd9b250a
#   - negative_486.jpg
#   - negative_487.jpg
#
# Hash: 3f44d3c340ffe3dc11c90c39f79fd936
#   - neutral_492.jpg
#   - neutral_491.jpg
#
# Hash: c67c886d49eb6e97e790be71452732a9
#   - negative_123.jpg
#   - negative_121.jpg
#
# Hash: 08d21b4400454cf07e50d0f3300c0678
#   - neutral_375.jpeg
#   - neutral_374.jpeg
#
# Hash: 04b31c84056a356a7ebe3f8814c25619
#   - positive_206.jpeg
#   - positive_205.jpeg
#
# Hash: ebc01a03ab317c1bcf21f0847d3b5e57
#   - neutral_526.jpg
#   - neutral_527.jpg
#
# Hash: d5538d9cfb11b304e09c37175a7592a1
#   - negative_547.jpeg
#   - negative_548.jpeg
#
# Hash: 0f826b0de33bb989009e29d2d6082e23
#   - neutral_355.jpeg
#   - neutral_356.jpeg
#
# Hash: 6a99b9ccd5fdb3dd182bd6e7c2f6f2a1
#   - neutral_514.jpg
#   - neutral_515.jpg
#
# Hash: 8a8a7cbd8f3884f3fe3d592231dae1bf
#   - negative_011.jpg
#   - negative_900.jpg
#
# Hash: c2a2d3c98f460f844fcfd169ab9a9b7e
#   - positive_170.jpeg
#   - positive_171.jpeg
#
# Hash: 2b6469045d385c61322d79c895f6373d
#   - neutral_153.jpeg
#   - neutral_611.jpeg
#
# Hash: c7deed00aa94d642f02e799b8ad36e91
#   - negative_173.jpg
#   - negative_172.jpg
#
# Hash: a7e58ea05a4e1a6dd60b91ae10325670
#   - negative_426.jpeg
#   - negative_427.jpeg
#
# Hash: 05c47a8df07924c8f9ffd1ae1460d02d
#   - negative_456.jpeg
#   - negative_457.jpeg
#
# Hash: 37e8b533a9a85919e7ea20628f418189
#   - neutral_354.jpg
#   - neutral_353.jpg
#
# Hash: 545c8d9192dd53918bb8546273ce2bbb
#   - negative_460.jpg
#   - negative_461.jpg
#
# Hash: 06f9c227237089a48f83271c4ad6c600
#   - neutral_209.png
#   - neutral_208.png
#
# Hash: 63b396cc487dddf0aa1764d26b8f9ad5
#   - neutral_284.jpg
#   - neutral_283.jpg
#
# Hash: 7e1c498fb4833e6015c75a6253102648
#   - negative_623.jpg
#   - negative_624.jpg
#
# Hash: 2bcad18e48c7d5a5daa7e0d42756234c
#   - negative_380.jpg
#   - negative_381.jpg
#
# Hash: a70cc1264cea5c083e8b15efe8549e66
#   - neutral_239.jpeg
#   - neutral_240.jpeg
#
# Hash: 2db9b607cb35b051d28fb2ff325bba9a
#   - neutral_440.jpeg
#   - neutral_441.jpeg
#
# Hash: a2af5af595398fcf2b49ad4ca4827eaa
#   - negative_119.jpg
#   - negative_117.jpg
#
# Hash: 897463f4b624c1d601a74d4d6bad9554
#   - neutral_108.jpg
#   - neutral_110.jpg
#
# Hash: e950fdcd10ab9c4316c0da2533683299
#   - positive_339.jpeg
#   - positive_340.jpeg
#
# Hash: 387f785014213ce4fcd39d94a2badc80
#   - positive_359.jpeg
#   - positive_358.jpeg
#
# Hash: ae371611ae4cc2dd02e359843a00c854
#   - neutral_397.jpg
#   - neutral_396.jpg
#
# Hash: 1a93f701bbfa60749e06e5f5f30c9e1d
#   - neutral_230.jpg
#   - neutral_231.jpg
#
# Hash: ca243560bf07dd1e5a8c45ff99af4d37
#   - neutral_472.jpg
#   - neutral_471.jpg
#
# Hash: 8d73f4dbfa662092c974f3948005ed04
#   - negative_444.jpeg
#   - negative_443.jpeg
#
# Hash: d445a3402ca2e760d7d88e5b2324ac1c
#   - neutral_290.jpeg
#   - neutral_289.jpeg
#
# Hash: d39186bf79ea4cae04f86314f244d16e
#   - negative_043.jpg
#   - negative_039.jpg
#
# Hash: 0f0d0f37080feb03fcf033332a6edd54
#   - neutral_160.jpg
#   - neutral_161.jpg
#
# Hash: 15f77fc877d258190d3ead1bfcf0e0a4
#   - negative_394.jpeg
#   - negative_395.jpeg
#
# Hash: ef90695e79547e3ac07e4626f62ba2b6
#   - positive_325.jpeg
#   - positive_326.jpeg
#
# Hash: 073a0d3bef2302978be7aad758ba86f6
#   - positive_520.jpeg
#   - positive_521.jpeg
#
# Hash: fcd4d4a4502488ef6a664f091ace0821
#   - negative_290.jpeg
#   - negative_291.jpeg
#
# Hash: e954d2f962b21e94421b87c730da0beb
#   - positive_478.jpeg
#   - positive_477.jpeg
#
# Hash: 9e5bd306e3a721a4aeb6060c87ccd9df
#   - positive_331.jpg
#   - positive_332.jpg
#
# Hash: 41a4693f3fb8128c58a5a2deda00867b
#   - negative_186.jpeg
#   - negative_187.jpeg
#
# Hash: f2df9455dccd7e336287db40c2b00bbc
#   - positive_743.jpg
#   - positive_772.jpg
#
# Hash: a4c14b885d728af2bf20b5ac55e06db7
#   - positive_393.jpeg
#   - positive_392.jpeg
#
# Hash: ece9b57d9d239b02c08b4f80fd73b64f
#   - positive_584.jpeg
#   - positive_583.jpeg
#
# Hash: c4a85130f11cf0a49f359b971c17d29f
#   - neutral_379.jpeg
#   - neutral_378.jpeg
#
# Hash: e446b27260718ee0c0a5be80bfdfc3a6
#   - neutral_328.jpeg
#   - neutral_329.jpeg
#
# Hash: 842d864426db7f6e080e046476a1821b
#   - positive_251.jpg
#   - positive_252.jpg
#
# Hash: 1f07fc77f6f73e13e5fb67f705f034f5
#   - neutral_651.jpeg
#   - neutral_652.jpeg
#
# Hash: 408bdcfdd56e3d3ded3ab4b78458dd6b
#   - negative_101.png
#   - negative_905.png
#
# Hash: 1015bd923ed330dbe413c64de3868cda
#   - negative_103.jpg
#   - negative_100.jpg
#
# Hash: ee15b8639b7fdd0a0437a314dc1bcfb7
#   - neutral_276.jpg
#   - neutral_275.jpg
#
# Hash: 632c1a471dc27449790bbf3d7b3f91c5
#   - negative_603.jpeg
#   - negative_602.jpeg
#
# Hash: 309ac280c935da7b922288be6aec1114
#   - negative_087.jpeg
#   - negative_086.jpeg
#
# Hash: aa46909c0d69550d9acfb99a20418f05
#   - neutral_327.jpg
#   - neutral_326.jpg
#
# Hash: 9b6b75240a134aef0a5f72518a66637b
#   - neutral_307.jpg
#   - neutral_308.jpg
#
# Hash: e90baf3cabf1b7c66fd4e85bb98493fa
#   - negative_229.jpg
#   - negative_228.jpg
#
# Hash: 1e5f933b43d61dab5910807ea648b33a
#   - positive_203.jpeg
#   - positive_204.jpeg
#
# Hash: 85802952325af33ee3a979c26d558bab
#   - positive_212.jpg
#   - positive_211.jpg
#
# Hash: 0c3fa369a426055d097847826ca6b313
#   - neutral_331.jpg
#   - neutral_330.jpg
#
# Hash: 41f95db756fbccb3c98416b1a4fd3722
#   - neutral_130.jpeg
#   - neutral_128.jpeg
#
# Hash: 89d59b8e6808e5eeadaecb443a1b5a39
#   - negative_293.jpeg
#   - negative_292.jpeg
#
# Hash: 4b0f629bf0b580ae1cad566207afd65b
#   - negative_205.jpeg
#   - negative_204.jpeg
#
# Hash: 1c2da135f5e6f24c3f4fa164701515ed
#   - positive_621.jpeg
#   - positive_622.jpeg
#
# Hash: 5c4a6716c138e773f1e911c47c8d096e
#   - negative_317.jpeg
#   - negative_316.jpeg
#
# Hash: f9c9320b5f23119309c4d7d2a9335f65
#   - neutral_647.jpeg
#   - neutral_646.jpeg
#
# Hash: 7c0c9ba998780a12d0e3daecd642d8e2
#   - negative_420.jpeg
#   - negative_421.jpeg
#
# Hash: 01d9ba6b7aeecb7a4e930aa4cb0c4339
#   - negative_615.jpg
#   - negative_616.jpg
#
# Hash: fcf1479285ebc230879bbe7e414454f0
#   - positive_450.jpeg
#   - positive_449.jpeg
#
# Hash: e8e5d15ff670393ee7f1bf8448b28ff9
#   - positive_263.jpg
#   - positive_264.jpg
#
# Hash: b3e3e6d218ddf45be782be439de26093
#   - neutral_632.jpg
#   - neutral_631.jpg
#
# Hash: 6ba6718993d0f277c3ffb601858c4d65
#   - negative_194.jpeg
#   - negative_195.jpeg
#
# Hash: 79aa0c8ff025b371f74c6c77ab4b6acd
#   - neutral_402.jpeg
#   - neutral_403.jpeg
#
# Hash: 371d5e24cff8366b6df0bb2c95a9f24b
#   - neutral_066.jpg
#   - neutral_151.jpg
#
# Hash: 2cdd0fe3ec313f373578b2939b9afdc5
#   - neutral_410.jpeg
#   - neutral_411.jpeg
#
# Hash: ffb09e9253e6b145a15bdecbe172d4fa
#   - positive_218.jpeg
#   - positive_217.jpeg
#
# Hash: 52f96e9c2a85d3794e6f2960e5e20c6b
#   - negative_184.jpg
#   - negative_185.jpg
#
# Hash: 3ed5051f223bff97be6437628f12541c
#   - negative_297.jpg
#   - negative_296.jpg
#
# Hash: 3aad0b01ac63fb7f62432d60c19a0725
#   - negative_527.jpeg
#   - negative_526.jpeg
#
# Hash: a8992bcc992e5c14f86edf339ca84ba3
#   - negative_333.jpg
#   - negative_332.jpg
#
# Hash: 51ea3c0641b3202e48dfe9cfe4a9a346
#   - negative_530.jpeg
#   - negative_531.jpeg
#
# Hash: cee86c402ddbe93a5aa2a1069a136e73
#   - neutral_298.jpeg
#   - neutral_297.jpeg
#
# Hash: c4e1fd11f6221690a809f47b0d1c8d20
#   - neutral_166.jpeg
#   - neutral_165.jpeg
#
# Hash: a24eb9191a5c4993b043142f8a72a306
#   - negative_566.jpeg
#   - negative_567.jpeg
#
# Hash: 0bcfa8448bfde828748d3e2b0a5611aa
#   - negative_067.jpg
#   - negative_070.jpg
#
# Hash: 95fc313ba4a95c4562208512117778a3
#   - positive_244.jpg
#   - positive_245.jpg
#
# Hash: 0f1e1a7540883c2d91687c7cb1e55d55
#   - neutral_242.jpg
#   - neutral_241.jpg
#
# Hash: 8b49585d8f0e3c427ad99e227cdf3b59
#   - negative_425.jpeg
#   - negative_424.jpeg
#
# Hash: 8aa923bd25c3da9fad46a5e043ec33e3
#   - negative_142.jpg
#   - negative_144.jpg
#
# Hash: 8a4bb92a15cbd8ed64441e8883079a28
#   - positive_308.jpeg
#   - positive_307.jpeg
#
# Hash: 2fb650d6ecab3316fd3d2b3d54751e83
#   - negative_314.jpeg
#   - negative_315.jpeg
#
# Hash: 5e48448ac0f16ad74617bcb73a826e5a
#   - negative_091.jpeg
#   - negative_090.jpeg
#
# Hash: 26a58e922305451599e62a3e8a74f042
#   - neutral_370.jpg
#   - neutral_369.jpg
#
# Hash: f4666f56e2972b53b3933a7d3c869a24
#   - negative_490.jpg
#   - negative_491.jpg
#
# Hash: 864212ecfa53d9fb71d26d465b246df5
#   - positive_534.jpeg
#   - positive_533.jpeg
#
# Hash: 9699177fd05953af20fbd92aa62fcf13
#   - neutral_442.jpg
#   - neutral_443.jpg
#
# Hash: 43871cb6005ad221c8149fd540cccbd8
#   - neutral_549.jpeg
#   - neutral_548.jpeg
#
# Hash: 8a483fd1ebf631f3584a7ce3a65e2fb6
#   - neutral_490.jpeg
#   - neutral_489.jpeg
#
# Hash: b9ecff70db088c7c05630d958b73a898
#   - negative_400.jpeg
#   - negative_401.jpeg
#
# Hash: 15b9e8024c43e4ae075e2686300e5d4c
#   - positive_292.jpeg
#   - positive_291.jpeg
#
# Hash: ebf3c5a9bab9daa07cba50cfa2a39feb
#   - neutral_507.jpg
#   - neutral_506.jpg
#
# Hash: 50e42cee30590209090de5b0629e58c3
#   - positive_247.jpg
#   - positive_246.jpg
#
# Hash: 9344b9738576e70bad16bbb732e021ac
#   - negative_469.jpeg
#   - negative_468.jpeg
#
# Hash: 00f30ef377c52043f8e79ae5cc75ec2e
#   - neutral_104.jpeg
#   - neutral_106.jpeg
#
# Hash: 973e54342e8a6f776cffbda5cd1149b4
#   - negative_393.jpeg
#   - negative_392.jpeg
#
# Hash: 9baa29291ad3ca03561379956f38649f
#   - negative_088.jpeg
#   - negative_904.jpeg
#
# Hash: 582dfa018a55fc7893e5423832153712
#   - negative_367.jpg
#   - negative_366.jpg
#
# Hash: b5b46a775850fd12cab165ecb785399b
#   - positive_193.jpg
#   - positive_194.jpg
#
# Hash: 2fd16d07073f633c438d07c3f887d127
#   - positive_623.jpeg
#   - positive_624.jpeg
#
# Hash: 335f8db4c384244e961567e2780a8fb6
#   - positive_012.jpeg
#   - positive_010.jpeg
#
# Hash: 4cbb19d9c18a4097f0720c63ed741a7c
#   - neutral_588.jpeg
#   - neutral_587.jpeg
#
# Hash: 30d33b5ae1fb0fbb5af94f344a37befc
#   - neutral_430.jpeg
#   - neutral_429.jpeg
#
# Hash: d1207a85e4e2f6033e671dbd380f9fcd
#   - neutral_421.jpg
#   - neutral_420.jpg
#
# Hash: 42fc1087324e72b83858617c6f1e3ea2
#   - positive_506.jpeg
#   - positive_505.jpeg
#
# Hash: e88d3e7f78094eea5ddd22911a303011
#   - positive_311.jpg
#   - positive_312.jpg
#
# Hash: ca9d32b47ac2522645040eabe04fcfdc
#   - neutral_197.jpeg
#   - neutral_196.jpeg
#
# Hash: 3595fd5923ef0a2aa5dfee93fb9b4a05
#   - neutral_237.png
#   - neutral_238.png
#
# Hash: 7587c0eb312d874cc79cb5025965d5cb
#   - neutral_522.jpg
#   - neutral_523.jpg
#
# Hash: 1d3f17ce8ac98fdec09fd0323dd4ab55
#   - positive_419.jpeg
#   - positive_418.jpeg
#
# Hash: 9dd31c802124e444815f88b1870281db
#   - positive_363.jpeg
#   - positive_364.jpeg
#
# Hash: d285db2026a9b297fab1787528c9deae
#   - negative_283.jpg
#   - negative_282.jpg
#
# Hash: d56aa9ab974879810cba85082ce52c9c
#   - positive_269.jpg
#   - positive_270.jpg
#
# Hash: 405da32dd9b41dfab3c9f5031b141eb5
#   - negative_372.jpeg
#   - negative_373.jpeg
#
# Hash: b8e69e81da4f3c0649dbea4511533f44
#   - negative_505.jpeg
#   - negative_506.jpeg
#
# Hash: 8485aa8c486cd321061e9cf65106c08f
#   - positive_603.jpeg
#   - positive_602.jpeg
#
# Hash: fc74bde3faa7b0b9006ad35d341daf8f
#   - positive_423.png
#   - positive_422.png
#
# Hash: 4e57221734a13204e4875c010b2e266a
#   - negative_357.jpeg
#   - negative_356.jpeg
#
# Hash: 427f03b6e89adaa237e1dc40d8fefba8
#   - positive_319.jpeg
#   - positive_320.jpeg
#
# Hash: d3ce1ab9261c62e1cebdb4c8f9484344
#   - neutral_273.jpeg
#   - neutral_274.jpeg
#
# Hash: c6288a712a15360ff37b0ac81c6af91f
#   - positive_167.jpg
#   - positive_166.jpg
#
# Hash: 17826f958aa44de317085a8906df5227
#   - neutral_399.jpeg
#   - neutral_398.jpeg
#
# Hash: cf36844aa5b60ce9308545dc53745271
#   - neutral_467.jpg
#   - neutral_468.jpg
#
# Hash: 2bc660dacc5d60a20adf7eee87950df9
#   - negative_280.jpg
#   - negative_281.jpg
#
# Hash: 491259ae8875bb8ad3446fb55f34b0f0
#   - neutral_612.jpg
#   - neutral_613.jpg
#
# Hash: 9605f7e6af619c5666d1108300a802e7
#   - positive_609.jpg
#   - positive_608.jpg
#
# Hash: 8915a8cfe167d782855b6440ff77e3a8
#   - negative_470.jpeg
#   - negative_471.jpeg
#
# Hash: eb0da69f98e8daff7503ced513fa932b
#   - positive_352.jpeg
#   - positive_351.jpeg
#
# Hash: f8bec33d0b0397d3fd9ee3941c26d32c
#   - positive_475.jpeg
#   - positive_474.jpeg
#
# Hash: 7f4d9f7f0290b938697200ace8471d3c
#   - neutral_413.jpg
#   - neutral_412.jpg
#
# Hash: fc4bfb293ec33abe8e9628c3323b7702
#   - positive_255.jpg
#   - positive_254.jpg
#
# Hash: 07829a32513b2bf10b2a4ecf3046a61f
#   - neutral_575.jpeg
#   - neutral_576.jpeg
#
# Hash: e89fbe613e83d1e6f456a33007f0b2fe
#   - negative_410.jpg
#   - negative_411.jpg
#
# Hash: 49818b1b60f61d33c307ab27d6dfb0ea
#   - positive_446.jpeg
#   - positive_445.jpeg
#
# Hash: 36e5a24381c0a919c2e1765abf52c667
#   - positive_202.jpeg
#   - positive_201.jpeg
#
# Hash: 9750ad9d3f08ae54947d10e13f4bd72d
#   - neutral_623.jpg
#   - neutral_624.jpg
#
# Hash: 080c0f4ec183ace0e7e4b02546231d80
#   - neutral_288.jpg
#   - neutral_287.jpg
#
# Hash: c083bec0c40d4f1957583a7cf6c0e094
#   - neutral_529.jpeg
#   - neutral_528.jpeg
#
# Hash: 9d3f1d5a8623df715fcccf053b3f2594
#   - neutral_037.jpg
#   - neutral_040.jpg
#
# Hash: 3f45a4eec6e5569d5efe8df95ff13fc2
#   - negative_313.jpg
#   - negative_312.jpg
#
# Hash: 6ddf48f24dd846146c0883b2d609c7b3
#   - negative_321.jpeg
#   - negative_320.jpeg
#
# Hash: 804a5e3deab565f53182c398441b7856
#   - negative_535.jpeg
#   - negative_536.jpeg
#
# Hash: bfd062427b01f8f4d7e1c5ca1759f696
#   - neutral_497.jpeg
#   - neutral_496.jpeg
#
# Hash: e34888c6fec1d43b3372e44a18d0f780
#   - neutral_569.jpg
#   - neutral_570.jpg
#
# Hash: d8d72a1ce23eca7938eda416131784ec
#   - neutral_323.jpg
#   - neutral_324.jpg
#
# Hash: d985e7f82a348a9661dec3fc300e3c9c
#   - negative_277.jpg
#   - negative_276.jpg
#
# Hash: ad844fd2b147bedd521318c7a82795e2
#   - positive_554.jpeg
#   - positive_555.jpeg
#
# Hash: a70f3dc915110cdf3373b4dc06c593d3
#   - negative_197.jpeg
#   - negative_196.jpeg
#
# Hash: ba65181531413d6c9b038bcc1be56e53
#   - negative_419.jpeg
#   - negative_418.jpeg
#
# Hash: 38d3b409632d3bef21bd80f38183fc86
#   - neutral_620.jpg
#   - neutral_619.jpg
#
# Hash: 8673036c7e1f7e1798964cae2a542878
#   - neutral_481.jpeg
#   - neutral_482.jpeg
#
# Hash: dc674a960e3275e5d2b26342ba6b675f
#   - neutral_268.jpg
#   - neutral_269.jpg
#
# Hash: 2a25f7e6b1fe15f8e35f0ec2afb4d616
#   - neutral_102.png
#   - neutral_100.png
#
# Hash: 4b7dda892d82f62cb638d35b20cbf762
#   - positive_594.jpeg
#   - positive_593.jpeg
#
# Hash: 7b774215af29e72c436420ed0877aa58
#   - neutral_280.jpg
#   - neutral_279.jpg
#
# Hash: eae88e2ff6cb7274da3507c69d0ae8c4
#   - negative_564.jpeg
#   - negative_563.jpeg
#
# Hash: 57feca15064b9bc4554c6d4afff425e7
#   - negative_203.jpeg
#   - negative_202.jpeg
#
# Hash: 4549bf8129a07273a4ebf6b6ffae6266
#   - neutral_519.jpg
#   - neutral_518.jpg
#
# Hash: fd988ad3f9e411bd4112e26ad16eba54
#   - positive_303.jpeg
#   - positive_304.jpeg

# %%
from collections import defaultdict
# Count duplicates by sentiment
sentiment_counts = defaultdict(int)

for dup_list in tqdm(duplicates.values(), desc="Sentiment wise scanning:"):
    for filename in dup_list:
        sentiment = filename.split('_')[0].lower()  # e.g. 'negative_001.png' → 'negative'
        sentiment_counts[sentiment] += 1

# Display results
if sentiment_counts:
    print("\nDuplicate image count by sentiment:")
    for sentiment, count in sentiment_counts.items():
        print(f"  {sentiment}: {count} duplicates")
else:
    print("No duplicate images found.")
# Out:
# Sentiment wise scanning::   0%|          | 0/771 [00:00<?, ?it/s]
# Duplicate image count by sentiment:
#   negative: 511 duplicates
#   neutral: 554 duplicates
#   positive: 527 duplicates

# %%
# Count duplicate **groups** by sentiment
sentiment_group_counts = defaultdict(int)

for dup_list in tqdm(duplicates.values(), desc="Sentiment wise scanning:"):
    # Use the first filename in the group to infer sentiment
    sentiment = dup_list[0].split('_')[0].lower()
    sentiment_group_counts[sentiment] += 1

# Display results
if sentiment_group_counts:
    print("\nDuplicate group count by sentiment:")
    for sentiment, count in sentiment_group_counts.items():
        print(f"  {sentiment}: {count} duplicate groups")
else:
    print("No duplicate images found.")
# Out:
# Sentiment wise scanning::   0%|          | 0/771 [00:00<?, ?it/s]
# Duplicate group count by sentiment:
#   negative: 250 duplicate groups
#   neutral: 263 duplicate groups
#   positive: 258 duplicate groups

# %% [markdown]
# ## Remove duplicates

# %%
import os
import hashlib
import shutil
from tqdm.notebook import tqdm

source_folder = '/kaggle/input/musait/dataset/basket'
destination_folder = 'basket_unique'

# Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

hash_set = set()
unique_files = []

# Get all image filenames
filenames = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

# Process with progress bar
for filename in tqdm(filenames, desc="Filtering unique images"):
    file_path = os.path.join(source_folder, filename)

    # Hash image content
    with open(file_path, 'rb') as f:
        file_hash = hashlib.md5(f.read()).hexdigest()

    # If new hash, copy file to unique folder
    if file_hash not in hash_set:
        hash_set.add(file_hash)
        shutil.copy(file_path, os.path.join(destination_folder, filename))
        unique_files.append(filename)

print(f"\n✔️ Finished! {len(unique_files)} unique images copied to: {destination_folder}")
# Out:
# Filtering unique images:   0%|          | 0/2875 [00:00<?, ?it/s]
# ✔️ Finished! 2054 unique images copied to: basket_unique

# %%
import zipfile

# Define zip filename
zip_filename = 'unique_images.zip'

# Create a zip file from the output folder
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for root, dirs, files in tqdm(os.walk(destination_folder), desc="Scanning files:"):
        # print(root,dirs)
        # print("_"*50)
        for file in files:
            full_path = os.path.join(root, file)
            arcname = os.path.relpath(full_path, destination_folder)
            zipf.write(full_path, arcname)

print(f"\n📦 Zipped folder ready: {zip_filename}")
# Out:
# Scanning files:: 0it [00:00, ?it/s]
# 📦 Zipped folder ready: unique_images.zip

# %% [markdown]
# # Feature analysis tables

# %%
# Create cross-tabulation table
sent_imgOr_table = pd.crosstab(df['sentiment'], df['img_or'])

print("____________________ Sentiment & Image Orientation contingency table ____________________")
print()
print(sent_imgOr_table)
# Out:
# ____________________ Sentiment & Image Orientation contingency table ____________________
#
# img_or     box  horizontal  other  vertical
# sentiment
# negative   118         706     27        56
# neutral    286         496     23       142
# positive   323         311     15       372

# %%
# Create cross-tabulation table
sent_imgAr_table = pd.crosstab(df['sentiment'], df['img_ar'])

print("____________________ Sentiment & Image Aspect Ratio contingency table ____________________")
print()
print(sent_imgAr_table)
# Out:
# ____________________ Sentiment & Image Aspect Ratio contingency table ____________________
#
# img_ar     16:9  1:1  21:9  2:1  2:3  3:2  3:4  4:3  5:4  9:16  Other
# sentiment
# negative    472  118     3    2    0   63   55  161    5     1     27
# neutral     308  286    10    6   11   59  126   97   16     5     23
# positive    133  323     0    2    4   85  368   84    7     0     15

# %%
# Create cross-tabulation table
sent_txtOr_table = pd.crosstab(df['sentiment'], df['txt_or'])

print("____________________ Sentiment & Text Orientation contingency table ____________________")
print()
print(sent_txtOr_table)
# Out:
# ____________________ Sentiment & Text Orientation contingency table ____________________
#
# txt_or     box  horizontal  other  vertical
# sentiment
# negative    96         439    264        63
# neutral    153         325    277       145
# positive   190         383    261       153

# %%
# Create cross-tabulation table
sent_txtAr_table = pd.crosstab(df['sentiment'], df['txt_ar'])

print("____________________ Sentiment & Text Aspect Ratio contingency table ____________________")
print()
print(sent_txtAr_table)
# Out:
# ____________________ Sentiment & Text Aspect Ratio contingency table ____________________
#
# txt_ar     16:9  1:1  21:9  2:1  2:3  2:5  3:2  3:4  4:3  5:4  9:16  Other
# sentiment
# negative    194   96    49   25    5    1   64   54   98    9     3    264
# neutral     108  153    58   28   24    8   43  104   74   14     9    277
# positive     70  190    51   32   12    2   56  136  157   17     3    261

# %%
# Create cross-tabulation table
txtAr_imgAr_table = pd.crosstab(df['txt_ar'],df['img_ar'])

print("____________________ Text Aspect Ratio & Image Aspect Ratio contingency table ____________________")
print()
print(txtAr_imgAr_table)
# Out:
# ____________________ Text Aspect Ratio & Image Aspect Ratio contingency table ____________________
#
# img_ar  16:9  1:1  21:9  2:1  2:3  3:2  3:4  4:3  5:4  9:16  Other
# txt_ar
# 16:9     270   22     0    0    2   12   34   20    3     0      9
# 1:1       48  271     1    0    0   20   65   26    5     0      3
# 21:9      85   23     2    0    0   13   17   12    1     0      5
# 2:1       52    8     0    0    0    4   16    4    0     0      1
# 2:3        4    8     0    0    6    4   19    0    0     0      0
# 2:5        0    1     0    0    1    0    5    0    0     4      0
# 3:2       49   32     0    0    3   30   13   34    0     0      2
# 3:4       17   69     2    0    2    4  184   15    0     1      0
# 4:3       53   91     0    0    0   32   43  102    2     0      6
# 5:4        5    9     0    0    1    4    5   11    5     0      0
# 9:16       1    8     0    0    0    1    4    0    0     1      0
# Other    307  160     6    6    0   48  132   99   12     0     32

# %%
# Create cross-tabulation table
txtOr_imgOr_table = pd.crosstab(df['txt_or'], df['img_or'])

print("____________________ Text Orientation & Image Orientation contingency table ____________________")
print()
print(txtOr_imgOr_table)
# Out:
# ____________________ Text Orientation & Image Orientation contingency table ____________________
#
# img_or      box  horizontal  other  vertical
# txt_or
# box         271         100      3        65
# horizontal  185         805     23       134
# other       160         478     32       132
# vertical     86          48      0       227

# %% [markdown]
# ## Hypothesis Testing on Text Orientation

# %%
import os
from PIL import Image
from collections import defaultdict, Counter
from scipy.stats import chi2_contingency

import numpy as np
import pandas as pd

# Contingency table
# data = np.array([
#     [370, 242, 409],  # Positive
#     [53, 645, 209],   # Negative
#     [139, 419, 389]   # Neutral
# ])

data = sent_txtOr_table.copy()

# Optional: Set labels
sentiments = ['positive', 'negative', 'neutral']
orientations = ['box', 'horizontal', 'other', 'vertical']

# df = pd.DataFrame(data, index=sentiments, columns=orientations)
# Contingency table

# Chi-square test
chi2, p, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic = {chi2:.3f}")
print(f"p-value = {p}")
print(f"Degrees of freedom = {dof}")
# Out:
# Chi-square statistic = 82.672
# p-value = 1.0015599339976698e-15
# Degrees of freedom = 6

# %%
sent_txtOr_table
# Out:
# txt_or     box  horizontal  other  vertical
# sentiment
# negative    96         439    264        63
# neutral    153         325    277       145
# positive   190         383    261       153

# %%
print("Expected frequencies (under H_0: No relationship):")
pd.DataFrame(np.round(expected, 2), index=sentiments, columns=orientations)
# Out:
# Expected frequencies (under H_0: No relationship):
#              box  horizontal   other  vertical
# positive  137.66      359.66  251.48    113.20
# negative  143.72      375.52  262.57    118.19
# neutral   157.62      411.82  287.95    129.61

# %%
print(f"p-value = {p}")
# Decision
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a relationship between orientation and sentiment.")
else:
    print("Fail to reject the null hypothesis: No significant relationship found.")
# Out:
# p-value = 1.0015599339976698e-15
# Reject the null hypothesis: There is a relationship between orientation and sentiment.

# %% [markdown]
# ## Hypothesis Testing on Image Orientation

# %%
import os
from PIL import Image
from collections import defaultdict, Counter
from scipy.stats import chi2_contingency

import numpy as np
import pandas as pd

# Contingency table
# data = np.array([
#     [370, 242, 409],  # Positive
#     [53, 645, 209],   # Negative
#     [139, 419, 389]   # Neutral
# ])

data = sent_imgOr_table.copy()

# Optional: Set labels
sentiments = ['positive', 'negative', 'neutral']
orientations = ['box', 'horizontal', 'other', 'vertical']

# df = pd.DataFrame(data, index=sentiments, columns=orientations)
# Contingency table

# Chi-square test
chi2, p, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic = {chi2:.3f}")
print(f"p-value = {p}")
print(f"Degrees of freedom = {dof}")
# Out:
# Chi-square statistic = 527.746
# p-value = 8.840667219230921e-111
# Degrees of freedom = 6

# %%
print("Expected frequencies:")
pd.DataFrame(np.round(expected, 2), index=sentiments, columns=orientations)
# Out:
# Expected frequencies:
#              box  horizontal  other  vertical
# positive  229.35      477.32  20.51    179.82
# negative  239.47      498.37  21.41    187.75
# neutral   258.18      537.31  23.08    202.42

# %%
print(f"p-value = {p}")
# Decision
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a relationship between orientation and sentiment.")
else:
    print("Fail to reject the null hypothesis: No significant relationship found.")
# Out:
# p-value = 8.840667219230921e-111
# Reject the null hypothesis: There is a relationship between orientation and sentiment.

# %% [markdown]
# ## Hypothesis Testing on Text-Image Ratio

# %%
type(df['txt_img_ratio'][0])
# Out:
# numpy.float64

# %%
import pandas as pd
import numpy as np

# Example: Ensure the column is numeric
col = pd.to_numeric(df['txt_img_ratio'], errors='coerce')

# Define bins (10 equal-width bins between 0 and 1)
bins = np.linspace(0, 1, 11)  # 11 edges = 10 bins
labels = [f"{round(bins[i],1)}–{round(bins[i+1],1)}" for i in range(len(bins)-1)]

# Add binned column
txt_img_bin = pd.cut(col, bins=bins, labels=labels, include_lowest=True)
df = pd.concat([df.iloc[:,:-1], txt_img_bin, df.iloc[:,-1]], axis=1)

# %%
df.columns.values[-2] = 'txt_img_ratio_bin'

# %%
df.head()
# Out:
#            filename                                           filepath  \
# 0  negative_001.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 1  negative_002.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 2  negative_003.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 3  negative_004.jpg  /kaggle/input/musait/dataset/basket/negative_0...
# 4  negative_005.jpg  /kaggle/input/musait/dataset/basket/negative_0...
#
#    text-detected                                                OCR  \
# 0              1   STOP WAR\nUKRAINE\nIN\nСлава Україні!\nMAKE\nNOT
# 1              1  HUNDREDS\nKILLED IN\nUKRAINE\n>NEWS\nNIGHTLY AT 6
# 2              0                                                NaN
# 3              0                                                NaN
# 4              1  HUNDREDS\nKILLED IN\nUKRAINE\n>NEWS\nNIGHTLY AT 6
#
#                                          coordinates img_ar      img_or  \
# 0  [{'x': 513, 'y': 24}, {'x': 975, 'y': 24}, {'x...   16:9  horizontal
# 1  [{'x': 20, 'y': 61}, {'x': 508, 'y': 61}, {'x'...   16:9  horizontal
# 2                                                 []   16:9  horizontal
# 3                                                 []    4:3  horizontal
# 4  [{'x': 20, 'y': 61}, {'x': 508, 'y': 61}, {'x'...   16:9  horizontal
#
#    img_area txt_ar      txt_or  txt_area  txt_img_ratio txt_img_ratio_bin  \
# 0    535824   16:9  horizontal    110418       0.206071           0.2–0.3
# 1    921600    3:4    vertical    313784       0.340477           0.3–0.4
# 2    810000    NaN         NaN         0       0.000000           0.0–0.1
# 3     50246    NaN         NaN         0       0.000000           0.0–0.1
# 4    921600    3:4    vertical    313784       0.340477           0.3–0.4
#
#   sentiment
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
import matplotlib.pyplot as plt

# Plot histogram directly from the data
plt.figure(figsize=(10, 5))
plt.hist(df['txt_img_ratio'], bins=10, color='skyblue', edgecolor='black')

plt.xlabel('txt_img_ratio')
plt.ylabel('Frequency')
plt.title('Histogram of txt_img_ratio (10 bins)')
plt.tight_layout()
plt.savefig("txt_img_ratio.png")
plt.show()

# %%
# Create cross-tabulation table
sent_ratioBin_table = pd.crosstab(df['sentiment'], df['txt_img_ratio_bin'])

print("____________________ Text Orientation & Image Orientation contingency table ____________________")
print()
sent_ratioBin_table
# Out:
# ____________________ Text Orientation & Image Orientation contingency table ____________________
# txt_img_ratio_bin  0.0–0.1  0.1–0.2  0.2–0.3  0.3–0.4  0.4–0.5  0.5–0.6  \
# sentiment
# negative                96      112       72       63       49       68
# neutral                153      112       83       93       63       76
# positive               140      177      168      128      117       92
#
# txt_img_ratio_bin  0.6–0.7  0.7–0.8  0.8–0.9  0.9–1.0
# sentiment
# negative               107       98      142      100
# neutral                 77      122      104       64
# positive                54       61       55       29

# %%
labels
# Out:
# ['0.0–0.1',
#  '0.1–0.2',
#  '0.2–0.3',
#  '0.3–0.4',
#  '0.4–0.5',
#  '0.5–0.6',
#  '0.6–0.7',
#  '0.7–0.8',
#  '0.8–0.9',
#  '0.9–1.0']

# %%
import os
from PIL import Image
from collections import defaultdict, Counter
from scipy.stats import chi2_contingency

import numpy as np
import pandas as pd

# Contingency table
# data = np.array([
#     [370, 242, 409],  # Positive
#     [53, 645, 209],   # Negative
#     [139, 419, 389]   # Neutral
# ])

data = sent_ratioBin_table.copy()

# Optional: Set labels
sentiments = ['positive', 'negative', 'neutral']
labels = ['0.0–0.1', '0.1–0.2', '0.2–0.3', '0.3–0.4', '0.4–0.5', '0.5–0.6', 
          '0.6–0.7', '0.7–0.8', '0.8–0.9', '0.9–1.0']

# df = pd.DataFrame(data, index=sentiments, columns=orientations)
# Contingency table

# Chi-square test
chi2, p, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic = {chi2:.3f}")
print(f"p-value = {p}")
print(f"Degrees of freedom = {dof}")
# Out:
# Chi-square statistic = 250.960
# p-value = 5.201173613652218e-43
# Degrees of freedom = 18

# %%
print("Expected frequencies:")
pd.DataFrame(np.round(expected, 2), index=sentiments, columns=labels)
# Out:
# Expected frequencies:
#           0.0–0.1  0.1–0.2  0.2–0.3  0.3–0.4  0.4–0.5  0.5–0.6  0.6–0.7  \
# positive   122.72   126.51   101.90    89.60    72.24    74.45    75.08
# negative   128.13   132.09   106.39    93.55    75.43    77.74    78.40
# neutral    138.15   142.41   114.71   100.86    81.32    83.81    84.52
#
#           0.7–0.8  0.8–0.9  0.9–1.0
# positive    88.65    94.96    60.89
# negative    92.56    99.15    63.57
# neutral     99.79   106.89    68.54

# %%
print(f"p-value = {p}")
# Decision
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a relationship between txt_img_ratio and sentiment.")
else:
    print("Fail to reject the null hypothesis: No significant relationship found.")
# Out:
# p-value = 5.201173613652218e-43
# Reject the null hypothesis: There is a relationship between txt_img_ratio and sentiment.

# %%
df.to_csv("all_info.csv", index=False)
