# %%
from google.cloud import vision
import io
import os

# Replace with your actual path to the JSON key file
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../google-cloud-vision-OCR-api/manifest-canto-466706-v0-1bb68556dfe3.json"

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.6

# %% [markdown]
# # Testing Google OCRs

# %%
def detect_labels(path):
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.label_detection(image=image)
    labels = response.label_annotations

    print('Labels:')
    for label in labels:
        print(f"{label.description} (score: {label.score:.2f})")

    if response.error.message:
        raise Exception(f'{response.error.message}')

# %%
# Example usage
detect_labels("negative_022.jpg")
# Out:
# Labels:
# Crowd (score: 0.83)
# Public event (score: 0.81)
# Banner (score: 0.80)
# Advertising (score: 0.77)
# Logo (score: 0.76)
# Smoke (score: 0.74)
# Protest (score: 0.68)
# High-rise building (score: 0.58)

# %%
import sys
# !{sys.executable} -m pip install "numpy<2.0" --force-reinstall --break-system-packages
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
from google.cloud import vision
from PIL import Image
import io
import matplotlib.pyplot as plt

# Initialize the Vision client
client = vision.ImageAnnotatorClient()

# Load your image
image_path = "negative_022.jpg"
with io.open(image_path, 'rb') as image_file:
    content = image_file.read()

image = vision.Image(content=content)

# Perform OCR (Text Detection)
response = client.text_detection(image=image)
texts = response.text_annotations

# Display results
if texts:
    print("Detected text:\n")
    print(texts[0].description)
else:
    print("No text detected.")

print(texts[0])

# Optional: Show image
img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Detected text:
#
# obc NEWS SPECIAL REPORT
# TWO BOMB EXPLOSIONS AT
# THE BOSTON MARATHON
# adidas
# locale: "en"
# description: "obc NEWS SPECIAL REPORT\nTWO BOMB EXPLOSIONS AT\nTHE BOSTON MARATHON\nadidas"
# bounding_poly {
#   vertices {
#     x: 56
#     y: 448
#   }
#   vertices {
#     x: 703
#     y: 448
#   }
#   vertices {
#     x: 703
#     y: 598
#   }
#   vertices {
#     x: 56
#     y: 598
#   }
# }

# %%
type(texts[0].bounding_poly.vertices[0])
# Out:
# google.cloud.vision_v1.types.geometry.Vertex

# %%
texts
# Out:
# [locale: "en"
# description: "obc NEWS SPECIAL REPORT\nTWO BOMB EXPLOSIONS AT\nTHE BOSTON MARATHON\nadidas"
# bounding_poly {
#   vertices {
#     x: 56
#     y: 448
#   }
#   vertices {
#     x: 703
#     y: 448
#   }
#   vertices {
#     x: 703
#     y: 598
#   }
#   vertices {
#     x: 56
#     y: 598
#   }
# }
# , description: "obc"
# bounding_poly {
#   vertices {
#     x: 56
#     y: 448
#   }
#   vertices {
#     x: 99
#     y: 448
#   }
#   vertices {
#     x: 99
#     y: 479
#   }
#   vertices {
#     x: 56
#     y: 479
#   }
# }
# , description: "NEWS"
# bounding_poly {
#   vertices {
#     x: 99
#     y: 448
#   }
#   vertices {
#     x: 208
#     y: 448
#   }
#   vertices {
#     x: 208
#     y: 479
#   }
#   vertices {
#     x: 99
#     y: 479
#   }
# }
# , description: "SPECIAL"
# bounding_poly {
#   vertices {
#     x: 221
#     y: 448
#   }
#   vertices {
#     x: 435
#     y: 448
#   }
#   vertices {
#     x: 435
#     y: 479
#   }
#   vertices {
#     x: 221
#     y: 479
#   }
# }
# , description: "REPORT"
# bounding_poly {
#   vertices {
#     x: 440
#     y: 448
#   }
#   vertices {
#     x: 646
#     y: 448
#   }
#   vertices {
#     x: 646
#     y: 479
#   }
#   vertices {
#     x: 440
#     y: 479
#   }
# }
# , description: "TWO"
# bounding_poly {
#   vertices {
#     x: 93
#     y: 494
#   }
#   vertices {
#     x: 167
#     y: 494
#   }
#   vertices {
#     x: 167
#     y: 518
#   }
#   vertices {
#     x: 93
#     y: 518
#   }
# }
# , description: "BOMB"
# bounding_poly {
#   vertices {
#     x: 180
#     y: 494
#   }
#   vertices {
#     x: 276
#     y: 494
#   }
#   vertices {
#     x: 276
#     y: 518
#   }
#   vertices {
#     x: 180
#     y: 518
#   }
# }
# , description: "EXPLOSIONS"
# bounding_poly {
#   vertices {
#     x: 289
#     y: 494
#   }
#   vertices {
#     x: 498
#     y: 494
#   }
#   vertices {
#     x: 498
#     y: 518
#   }
#   vertices {
#     x: 289
#     y: 518
#   }
# }
# , description: "AT"
# bounding_poly {
#   vertices {
#     x: 510
#     y: 494
#   }
#   vertices {
#     x: 550
#     y: 494
#   }
#   vertices {
#     x: 550
#     y: 518
#   }
#   vertices {
#     x: 510
#     y: 518
#   }
# }
# , description: "THE"
# bounding_poly {
#   vertices {
#     x: 94
#     y: 524
#   }
#   vertices {
#     x: 158
#     y: 524
#   }
#   vertices {
#     x: 158
#     y: 549
#   }
#   vertices {
#     x: 94
#     y: 549
#   }
# }
# , description: "BOSTON"
# bounding_poly {
#   vertices {
#     x: 172
#     y: 524
#   }
#   vertices {
#     x: 305
#     y: 524
#   }
#   vertices {
#     x: 305
#     y: 549
#   }
#   vertices {
#     x: 172
#     y: 549
#   }
# }
# , description: "MARATHON"
# bounding_poly {
#   vertices {
#     x: 320
#     y: 524
#   }
#   vertices {
#     x: 504
#     y: 524
#   }
#   vertices {
#     x: 504
#     y: 549
#   }
#   vertices {
#     x: 320
#     y: 549
#   }
# }
# , description: "adidas"
# bounding_poly {
#   vertices {
#     x: 614
#     y: 564
#   }
#   vertices {
#     x: 703
#     y: 568
#   }
#   vertices {
#     x: 702
#     y: 598
#   }
#   vertices {
#     x: 613
#     y: 594
#   }
# }
# ]

# %%
type(content)
# Out:
# bytes

# %% [markdown]
# # Google Cloud Vision OCR

# %%
# !pip install --upgrade opencv-python --break-system-packages
# Out:
# Requirement already satisfied: opencv-python in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (from opencv-python) (2.2.6)

# %%
# !pip install pandas==2.2.2 --break-system-packages
# Out:
# Requirement already satisfied: pandas==2.2.2 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (from pandas==2.2.2) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/soham/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import numpy as np

# %%
def get_gcv_ocr(content):
    client = vision.ImageAnnotatorClient()
    image = vision.Image(content=content)

    # Perform OCR (Text Detection)
    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    # texts[0] contains all info about the entire line of detected text
    # texts[0].description contains the entire line of detected text
    
    return texts


def get_orientation(coordinates):
    A,B,C,D = coordinates[0],coordinates[1],coordinates[2],coordinates[3]
    # A -> Lower left
    # B -> Lower right
    # C -> Upper right
    # D -> Upper left

# %%
print("Number of files =",len(os.listdir('../../dataset/basket')))
# Out:
# Number of files = 2875

# %%
root = "../../dataset/basket"

# %%
files = os.listdir(root)
files.sort()

columns = ["filename", "filepath", "text-detected", "OCR", "coordinates", "sentiment"]
ocr = pd.DataFrame(columns=columns)

# %%
# ocr.loc[2] = ["fdfs","fsf","fsf","negative"]
ocr
# Out:
# Empty DataFrame
# Columns: [filename, filepath, text-detected, OCR, coordinates, sentiment]
# Index: []

# %%
# import cv2
count = 0
for file in files:
    filepath = root+"/"+file
    print(filepath)
    with io.open(filepath, 'rb') as image_file:
        content = image_file.read()
    
    texts = get_gcv_ocr(content)

    coordinates = []
    text = ""
    flag = 0 # text detection flag
    if texts:
        # print("Detected text:\n")
        flag = 1
        text = texts[0].description
        bounding_poly = texts[0].bounding_poly
        for vertex in bounding_poly.vertices:
            coordinates.append({"x": vertex.x, "y": vertex.y})

    # if coordinates!=[]:
    #     orientation = get_orientation(coordinates)

    ocr.loc[count] = [file, filepath, flag, text, coordinates, file.split("_")[0]]
    count+=1
    # break
# Out:
# ../../dataset/basket/negative_001.jpg
# ../../dataset/basket/negative_002.jpg
# ../../dataset/basket/negative_003.jpg
# ../../dataset/basket/negative_004.jpg
# ../../dataset/basket/negative_005.jpg
# ../../dataset/basket/negative_006.jpg
# ../../dataset/basket/negative_007.jpg
# ../../dataset/basket/negative_008.jpg
# ../../dataset/basket/negative_009.jpg
# ../../dataset/basket/negative_010.jpg
# ../../dataset/basket/negative_011.jpg
# ../../dataset/basket/negative_012.jpg
# ../../dataset/basket/negative_013.jpg
# ../../dataset/basket/negative_014.jpg
# ../../dataset/basket/negative_015.jpg
# ../../dataset/basket/negative_016.jpg
# ../../dataset/basket/negative_017.jpg
# ../../dataset/basket/negative_018.jpg
# ../../dataset/basket/negative_019.jpg
# ../../dataset/basket/negative_020.jpg
# ../../dataset/basket/negative_021.jpeg
# ../../dataset/basket/negative_022.jpg
# ../../dataset/basket/negative_023.jpeg
# ../../dataset/basket/negative_024.jpg
# ../../dataset/basket/negative_025.jpg
# ../../dataset/basket/negative_026.jpeg
# ../../dataset/basket/negative_027.jpg
# ../../dataset/basket/negative_028.jpg
# ../../dataset/basket/negative_029.jpg
# ../../dataset/basket/negative_030.jpg
# ../../dataset/basket/negative_031.jpg
# ../../dataset/basket/negative_032.jpg
# ../../dataset/basket/negative_033.jpg
# ../../dataset/basket/negative_034.jpg
# ../../dataset/basket/negative_035.jpg
# ../../dataset/basket/negative_036.jpeg
# ../../dataset/basket/negative_037.jpg
# ../../dataset/basket/negative_038.jpg
# ../../dataset/basket/negative_039.jpg
# ../../dataset/basket/negative_040.jpg
# ../../dataset/basket/negative_041.jpeg
# ../../dataset/basket/negative_042.jpg
# ../../dataset/basket/negative_043.jpg
# ../../dataset/basket/negative_044.jpg
# ../../dataset/basket/negative_704.jpg
# ../../dataset/basket/negative_705.jpg
# ../../dataset/basket/negative_706.jpg
# ../../dataset/basket/negative_707.jpg
# ../../dataset/basket/negative_708.jpg
# ../../dataset/basket/negative_709.jpg
# ../../dataset/basket/negative_710.jpg
# ../../dataset/basket/negative_711.jpg
# ../../dataset/basket/negative_712.jpg
# ../../dataset/basket/negative_713.jpg
# ../../dataset/basket/negative_714.jpg
# ../../dataset/basket/negative_715.jpg
# ../../dataset/basket/negative_716.jpg
# ../../dataset/basket/negative_717.jpg
# ../../dataset/basket/negative_718.jpg
# ../../dataset/basket/negative_719.jpg
# ../../dataset/basket/negative_720.jpg
# ../../dataset/basket/negative_721.jpg
# ../../dataset/basket/negative_722.jpg
# ../../dataset/basket/negative_723.jpg
# ../../dataset/basket/negative_724.jpg
# ../../dataset/basket/negative_725.jpg
# ../../dataset/basket/negative_726.jpg
# ../../dataset/basket/negative_727.jpg
# ../../dataset/basket/negative_728.jpg
# ../../dataset/basket/negative_729.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 9
#       6 with io.open(filepath, 'rb') as image_file:
#       7     content = image_file.read()
# ----> 9 texts = get_gcv_ocr(content)
#      11 coordinates = []
#      12 text = ""
#
# Cell In[28], line 6, in get_gcv_ocr(content)
#       3 image = vision.Image(content=content)
#       5 # Perform OCR (Text Detection)
# ----> 6 response = client.text_detection(image=image)
#       7 texts = response.text_annotations
#       9 # texts[0] contains all info about the entire line of detected text
#      10 # texts[0].description contains the entire line of detected text
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/google/cloud/vision_helpers/decorators.py:112, in _create_single_feature_method.<locals>.inner(self, image, max_results, retry, timeout, metadata, **kwargs)
#     110     copied_features["max_results"] = max_results
#     111 request = dict(image=image, features=[copied_features], **kwargs)
# --> 112 response = self.annotate_image(
#     113     request, retry=retry, timeout=timeout, metadata=metadata
#     114 )
#     115 return response
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/google/cloud/vision_helpers/__init__.py:76, in VisionHelpers.annotate_image(self, request, retry, timeout, metadata)
#      74 elif len(request.features) == 0:
#      75     request.features = self._get_all_features()
# ---> 76 r = self.batch_annotate_images(
#      77     requests=[request], retry=retry, timeout=timeout, metadata=metadata
#      78 )
#      79 return r.responses[0]
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/google/cloud/vision_v1/services/image_annotator/client.py:839, in ImageAnnotatorClient.batch_annotate_images(self, request, requests, retry, timeout, metadata)
#     836 self._validate_universe_domain()
#     838 # Send the request.
# --> 839 response = rpc(
#     840     request,
#     841     retry=retry,
#     842     timeout=timeout,
#     843     metadata=metadata,
#     844 )
#     846 # Done; return the response.
#     847 return response
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/google/cloud/vision_v1/services/image_annotator/transports/grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)
#      76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/grpc/_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/Documents/ISI_RI/msa-venv/lib/python3.10/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:395, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:207, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:201, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:62, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:58, in grpc._cython.cygrpc._interpret_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/tag.pyx.pxi:71, in grpc._cython.cygrpc._BatchOperationTag.event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/operation.pyx.pxi:138, in grpc._cython.cygrpc.ReceiveInitialMetadataOperation.un_c()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:69, in grpc._cython.cygrpc._metadata()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:70, in genexpr()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:64, in grpc._cython.cygrpc._metadatum()
#
# File <string>:1, in <lambda>(_cls, key, value)
#
# KeyboardInterrupt:

# %%
ocr
# Out:
#              filename                                filepath  \
# 0    negative_001.jpg   ../../dataset/basket/negative_001.jpg
# 1    negative_002.jpg   ../../dataset/basket/negative_002.jpg
# 2    negative_003.jpg   ../../dataset/basket/negative_003.jpg
# 3    negative_004.jpg   ../../dataset/basket/negative_004.jpg
# 4    negative_005.jpg   ../../dataset/basket/negative_005.jpg
# 5    negative_006.jpg   ../../dataset/basket/negative_006.jpg
# 6    negative_007.jpg   ../../dataset/basket/negative_007.jpg
# 7    negative_008.jpg   ../../dataset/basket/negative_008.jpg
# 8    negative_009.jpg   ../../dataset/basket/negative_009.jpg
# 9    negative_010.jpg   ../../dataset/basket/negative_010.jpg
# 10   negative_011.jpg   ../../dataset/basket/negative_011.jpg
# 11   negative_012.jpg   ../../dataset/basket/negative_012.jpg
# 12   negative_013.jpg   ../../dataset/basket/negative_013.jpg
# 13   negative_014.jpg   ../../dataset/basket/negative_014.jpg
# 14   negative_015.jpg   ../../dataset/basket/negative_015.jpg
# 15   negative_016.jpg   ../../dataset/basket/negative_016.jpg
# 16   negative_017.jpg   ../../dataset/basket/negative_017.jpg
# 17   negative_018.jpg   ../../dataset/basket/negative_018.jpg
# 18   negative_019.jpg   ../../dataset/basket/negative_019.jpg
# 19   negative_020.jpg   ../../dataset/basket/negative_020.jpg
# 20  negative_021.jpeg  ../../dataset/basket/negative_021.jpeg
# 21   negative_022.jpg   ../../dataset/basket/negative_022.jpg
# 22  negative_023.jpeg  ../../dataset/basket/negative_023.jpeg
# 23   negative_024.jpg   ../../dataset/basket/negative_024.jpg
# 24   negative_025.jpg   ../../dataset/basket/negative_025.jpg
# 25  negative_026.jpeg  ../../dataset/basket/negative_026.jpeg
# 26   negative_027.jpg   ../../dataset/basket/negative_027.jpg
# 27   negative_028.jpg   ../../dataset/basket/negative_028.jpg
# 28   negative_029.jpg   ../../dataset/basket/negative_029.jpg
# 29   negative_030.jpg   ../../dataset/basket/negative_030.jpg
# 30   negative_031.jpg   ../../dataset/basket/negative_031.jpg
# 31   negative_032.jpg   ../../dataset/basket/negative_032.jpg
# 32   negative_033.jpg   ../../dataset/basket/negative_033.jpg
# 33   negative_034.jpg   ../../dataset/basket/negative_034.jpg
# 34   negative_035.jpg   ../../dataset/basket/negative_035.jpg
# 35  negative_036.jpeg  ../../dataset/basket/negative_036.jpeg
# 36   negative_037.jpg   ../../dataset/basket/negative_037.jpg
# 37   negative_038.jpg   ../../dataset/basket/negative_038.jpg
# 38   negative_039.jpg   ../../dataset/basket/negative_039.jpg
# 39   negative_040.jpg   ../../dataset/basket/negative_040.jpg
# 40  negative_041.jpeg  ../../dataset/basket/negative_041.jpeg
# 41   negative_042.jpg   ../../dataset/basket/negative_042.jpg
# 42   negative_043.jpg   ../../dataset/basket/negative_043.jpg
# 43   negative_044.jpg   ../../dataset/basket/negative_044.jpg
# 44   negative_045.jpg   ../../dataset/basket/negative_045.jpg
# 45  negative_046.jpeg  ../../dataset/basket/negative_046.jpeg
# 46   negative_047.jpg   ../../dataset/basket/negative_047.jpg
# 47   negative_048.jpg   ../../dataset/basket/negative_048.jpg
# 48   negative_049.jpg   ../../dataset/basket/negative_049.jpg
# 49   negative_050.jpg   ../../dataset/basket/negative_050.jpg
# 50  negative_051.jpeg  ../../dataset/basket/negative_051.jpeg
# 51   negative_052.jpg   ../../dataset/basket/negative_052.jpg
# 52   negative_053.jpg   ../../dataset/basket/negative_053.jpg
# 53   negative_054.jpg   ../../dataset/basket/negative_054.jpg
# 54   negative_055.jpg   ../../dataset/basket/negative_055.jpg
# 55  negative_056.jpeg  ../../dataset/basket/negative_056.jpeg
# 56   negative_057.jpg   ../../dataset/basket/negative_057.jpg
# 57  negative_058.jpeg  ../../dataset/basket/negative_058.jpeg
#
#                                                   OCR sentiment
# 0    STOP WAR\nUKRAINE\nIN\nСлава Україні!\nMAKE\nNOT  negative
# 1   HUNDREDS\nKILLED IN\nUKRAINE\n>NEWS\nNIGHTLY AT 6  negative
# 2                                                      negative
# 3                                                      negative
# 4   HUNDREDS\nKILLED IN\nUKRAINE\n>NEWS\nNIGHTLY AT 6  negative
# 5   R. TURKEY TO HOST TALKS?\nWORLD\nAT WAR\nR. BR...  negative
# 6   UKRAINE UNDER ATTACK\nRUSSIAN SHELLING IN OKHT...  negative
# 7                                             VIS\nAP  negative
# 8                                                      negative
# 9   UKRAINE UNDER ATTACK\nRUSSIAN SHELLING IN OKHT...  negative
# 10  REPRINT BROUGHT TO YOU BY M-C ASSOCIATES\nWAR ...  negative
# 11         J&K: 7 ARMY PERSONNEL\nKILLED SINCE MONDAY  negative
# 12                                                     negative
# 13                                                     negative
# 14         J&K: 7 ARMY PERSONNEL\nKILLED SINCE MONDAY  negative
# 15  Copyrighterl\nThe Des Moines Register JAPAN DE...  negative
# 16          CYCLONE\nAMPHAN\nINDIATV\nindiatvnews.com  negative
# 17                                                     negative
# 18                                                     negative
# 19          CYCLONE\nAMPHAN\nINDIATV\nindiatvnews.com  negative
# 20  SINK 3 SHIPS OFF TOKIO\nR\n22 DEAD ON PLANE\nC...  negative
# 21  obc NEWS SPECIAL REPORT\nTWO BOMB EXPLOSIONS A...  negative
# 22  SINK 3 SHIPS OFF TOKIO\nR\n22 DEAD ON PLANE\nC...  negative
# 23                                                     negative
# 24                                                     negative
# 25  BALTIMORE NEWS-POST NIGHT\nRACE SPECIAL\nGERMA...  negative
# 26                AFTERMATH OF\nCYCLONE AMPHAN\nCRUX.  negative
# 27                                                     negative
# 28                                                     negative
# 29                AFTERMATH OF\nCYCLONE AMPHAN\nCRUX.  negative
# 30  # RUSSIAUKARINE CONFLICT\n| हमले के बाद\nरिहाय...  negative
# 31  INDIA-CHINA GALWAN STAND-OFF:\nAT LEAST 20 SOL...  negative
# 32                                                     negative
# 33                                                     negative
# 34  INDIA-CHINA GALWAN STAND-OFF:\nAT LEAST 20 SOL...  negative
# 35                        Nit Jamshedpur\nFrustration  negative
# 36  JAMMU AND KASHMIR\n5 SOLDIERS KILLED IN POONCH...  negative
# 37                                                     negative
# 38                                                     negative
# 39  JAMMU AND KASHMIR\n5 SOLDIERS KILLED IN POONCH...  negative
# 40                           BAN\nRUSSIA\nFROM\nSWIFT  negative
# 41  RISID BUS\nগ্রীন হইতে হাওড়া (\nTATA\nRIS-110\...  negative
# 42                                                     negative
# 43                                                     negative
# 44  RISID BUS\nগ্রীন হইতে হাওড়া (\nTATA\nRIS-110\...  negative
# 45  DAILY PAPER\nMason City Globe-Gazette\nU.S. DE...  negative
# 46                           CYCLONE TAUKTAE\nR. NEWS  negative
# 47                                                     negative
# 48            Thank you\nfor driving\ncarefully\nCars  negative
# 49                           CYCLONE TAUKTAE\nR. NEWS  negative
# 50                              DUNE DO NOT C\nMURDER  negative
# 51  SUPER CYCLONE,AMPHAN INTENSIFIES\n520 KM FROM ...  negative
# 52                                                     negative
# 53                                                     negative
# 54  SUPER CYCLONE,AMPHAN INTENSIFIES\n520 KM FROM ...  negative
# 55                             NOT CUTE\nJUST\nPSYCHO  negative
# 56  CYCLONE AMPHAN HITS INDIA\n4 DEAD IN WEST BENG...  negative
# 57                                                     negative
